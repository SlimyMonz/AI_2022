# %% [markdown]
# # Recurrent Neural Network Homework
#
# This is the 4th assignment for CAP 4630 and we will implement a basic RNN network and an LSTM network with Keras to solve two problems. \
# You will use **"Tasks"** and **"Hints"** to finish the work. **(Total 100 points, including 15 bonus points)** \
# You may use Machine Learning libaries like Scikit-learn for data preprocessing.
#
# **Task Overview:**
# - Implement a basic RNN network to solve time series prediction
# - Implement an LSTM network to conduct sentiment analysis

# %% [markdown]
# ## 1 - Implement Basic RNN network with Keras to predict time series##
# ### 1.1 Prepare the data (17 Points)
#
# Prepare time series data for deep neural network training.
#
# **Tasks:**
# 1. Load the given train and test data: "train.txt" and "test.txt". **(5 Points)**
# 2. Generate the **TRAIN** and **TEST** labels. **(5 Points)**
# 3. Normalize the **TRAIN** and **TEST** data with sklearn function "MinMaxScaler". **(5 Points)**
# 4. **PRINT OUT** the **TEST** data and label. **(2 Points)**
#
# **Hints:**
# 1. The length of original train data is 113 which starts from **"1949-01"** to **"1958-05"**. The length of original test data is 29, which starts from **"1958-07"** to **"1960-11"**.
# 2. Set the data types of both train and test data to "float32".
# 3. When you prepared input data X (sequences) and oupt data Y (labels), please consider the following relationship:
#     - The sequence X should be the **past 12** datapoints in the time series, i.e., observation sequence with historical window of 12. You may check the time series data and think about the reason.
#     - The label Y should be the **next 1** datapoint in the time series (one point ahead prediction).
# 4. The first 3 **TRAIN** data and label should be:
#
# - trainX[0] = [[0.02203858 &nbsp; 0.03856748 &nbsp; 0.077135 &nbsp;  0.06887051 &nbsp; 0.04683197 &nbsp; 0.08539945 &nbsp; 0.12121212 &nbsp; 0.12121212 &nbsp; 0.08815429 &nbsp; 0.04132232 &nbsp; 0.    &nbsp; 0.03856748]]
# - trainY[0] = [0.03030303]
#
# - trianX[1] = [[0.03856748 &nbsp; 0.077135 &nbsp;  0.06887051 &nbsp; 0.04683197  &nbsp; 0.08539945  &nbsp; 0.12121212  &nbsp; 0.12121212  &nbsp; 0.08815429  &nbsp; 0.04132232  &nbsp; 0.     &nbsp;  0.03856748   &nbsp; 0.03030303]]
# - trainY[1] = [0.06060606]
#
# - trainX[2] =  [[0.077135 &nbsp;  0.06887051 &nbsp; 0.04683197 &nbsp; 0.08539945 &nbsp; 0.12121212 &nbsp; 0.12121212 &nbsp; 0.08815429 &nbsp; 0.04132232 &nbsp; 0.    &nbsp;     0.03856748 &nbsp; 0.03030303 &nbsp; 0.06060606]]
# - trainY[2] = [0.10192838]
#
# 5. Apply the MinMaxScaler to both the train and test data.\
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html
#
#
# 6. After the preparation with scaler fitting, the shapes of trainX, trainY, testX, and testY are as follows:\
# trainX.shape = (101, 1, 12)\
# trainY.shape = (101,)\
# testX.shape = (17, 1, 12)\
# testY.shape = (17,)

# %%
### Import Libraries ###

import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.layers 
import random
import numpy as np

### Set random seed to ensure deterministic results
import os
seed_value = 1
os.environ['PYTHONHASHSEED']=str(seed_value)
def reset_random_seeds():
   tf.random.set_seed(seed_value)
   np.random.seed(seed_value)
   random.seed(seed_value)
reset_random_seeds()

# %%
### Prepare and Preprocess Data Here ###
from pandas import read_csv

# NOTE: REPLACE THESE LINES WITH YOUR OWN!!!! WILL NOT WORK OTHERWISE
from google.colab import drive
drive.mount('/content/drive')
# THE FILE!!! please for the love of god 
TEST_TXT = './drive/MyDrive/HW4/test.txt'
TRAIN_TXT = './drive/MyDrive/HW4/train.txt'
# SERIOUSLY 


### Design a Function to Prepare Observation Sequences and Corresponding Labels ###

def create_dataset(dataset, look_back=12): # look_back is used to specify input sequence length
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back):
		dataX.append(dataset[i:(i + look_back), 0]) 
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

### Train and Test Data Loading with float32 type ####
dataframe_train = read_csv(TRAIN_TXT, usecols=[1], engine='python') # Read train.txt 
dataset_train = dataframe_train.values
dataset_train = dataset_train.astype('float32') # Specify the data type to 'float32'

dataframe_test = read_csv(TEST_TXT, usecols=[1], engine='python') # Read test.txt 
dataset_test = dataframe_test.values
dataset_test = dataset_test.astype('float32') # Specify the data type to 'float32'


### Scale Training and Test Data to [0, 1] ###
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1)) # specify the scaler
train = scaler.fit_transform(dataset_train) # fit the scaler to the training data
test = scaler.transform(dataset_test) # fit the scaler to the test data

### Training and Test Data Split ###
trainX, trainY = create_dataset(train, look_back=12)
testX, testY = create_dataset(test, look_back=12)

### Training and Test Data Reshape (to fit RNN input) ###
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
# Out:
# Mounted at /content/drive

# %%
### Print Out the TEST Data and Labels Here ###
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)

print(trainX)
print(trainY)

print(testX)
print(testY)
# Out:
# (101, 1, 12)
# (101,)
# (17, 1, 12)
# (17,)
# [[[0.02203858 0.03856748 0.077135   ... 0.04132232 0.         0.03856748]]
#
#  [[0.03856748 0.077135   0.06887051 ... 0.         0.03856748 0.03030303]]
#
#  [[0.077135   0.06887051 0.04683197 ... 0.03856748 0.03030303 0.06060606]]
#
#  ...
#
#  [[0.69421494 0.67217636 0.69146    ... 0.63911843 0.6501378  0.58953166]]
#
#  [[0.67217636 0.69146    0.87603307 ... 0.6501378  0.58953166 0.7107438 ]]
#
#  [[0.69146    0.87603307 0.9944904  ... 0.58953166 0.7107438  0.67217636]]]
# [0.03030303 0.06060606 0.10192838 0.08539945 0.05785125 0.12396696
#  0.18181819 0.18181819 0.14876035 0.0798898  0.02754822 0.09917355
#  0.11294767 0.12672177 0.20385677 0.16253445 0.18732783 0.20385677
#  0.261708   0.261708   0.2203857  0.15977961 0.11570248 0.1707989
#  0.184573   0.20936641 0.24517909 0.21212122 0.21763083 0.31404957
#  0.34710744 0.3801653  0.2892562  0.23966941 0.18732783 0.2479339
#  0.2534435  0.2534435  0.36363634 0.36088154 0.34435263 0.38292012
#  0.44077137 0.46280995 0.3663912  0.29476586 0.20936641 0.26721767
#  0.2754821  0.23140499 0.36088154 0.33884296 0.35812673 0.44077137
#  0.5454545  0.5206611  0.42699727 0.34435263 0.27272728 0.34435263
#  0.3801653  0.35537192 0.4490358  0.45454547 0.45730028 0.58126724
#  0.7162534  0.66942155 0.5730028  0.46831957 0.3663912  0.47933885
#  0.49586776 0.47658405 0.58677685 0.5757576  0.58953166 0.7438016
#  0.8512397  0.8292011  0.69146    0.55647385 0.46005508 0.55647385
#  0.58126724 0.5426997  0.69421494 0.67217636 0.69146    0.87603307
#  0.9944904  1.         0.8264463  0.66942155 0.55371904 0.63911843
#  0.6501378  0.58953166 0.7107438  0.67217636 0.7134986 ]
# [[[1.0661157  1.1046832  0.8264463  0.70247936 0.5674931  0.64187324
#    0.70523417 0.6556474  0.8319559  0.8044077  0.87052345 1.013774  ]]
#
#  [[1.1046832  0.8264463  0.70247936 0.5674931  0.64187324 0.70523417
#    0.6556474  0.8319559  0.8044077  0.87052345 1.013774   1.2231405 ]]
#
#  [[0.8264463  0.70247936 0.5674931  0.64187324 0.70523417 0.6556474
#    0.8319559  0.8044077  0.87052345 1.013774   1.2231405  1.2534435 ]]
#
#  [[0.70247936 0.5674931  0.64187324 0.70523417 0.6556474  0.8319559
#    0.8044077  0.87052345 1.013774   1.2231405  1.2534435  0.98898065]]
#
#  [[0.5674931  0.64187324 0.70523417 0.6556474  0.8319559  0.8044077
#    0.87052345 1.013774   1.2231405  1.2534435  0.98898065 0.8347107 ]]
#
#  [[0.64187324 0.70523417 0.6556474  0.8319559  0.8044077  0.87052345
#    1.013774   1.2231405  1.2534435  0.98898065 0.8347107  0.7107438 ]]
#
#  [[0.70523417 0.6556474  0.8319559  0.8044077  0.87052345 1.013774
#    1.2231405  1.2534435  0.98898065 0.8347107  0.7107438  0.8292011 ]]
#
#  [[0.6556474  0.8319559  0.8044077  0.87052345 1.013774   1.2231405
#    1.2534435  0.98898065 0.8347107  0.7107438  0.8292011  0.8622589 ]]
#
#  [[0.8319559  0.8044077  0.87052345 1.013774   1.2231405  1.2534435
#    0.98898065 0.8347107  0.7107438  0.8292011  0.8622589  0.79063356]]
#
#  [[0.8044077  0.87052345 1.013774   1.2231405  1.2534435  0.98898065
#    0.8347107  0.7107438  0.8292011  0.8622589  0.79063356 0.8677685 ]]
#
#  [[0.87052345 1.013774   1.2231405  1.2534435  0.98898065 0.8347107
#    0.7107438  0.8292011  0.8622589  0.79063356 0.8677685  0.98347104]]
#
#  [[1.013774   1.2231405  1.2534435  0.98898065 0.8347107  0.7107438
#    0.8292011  0.8622589  0.79063356 0.8677685  0.98347104 1.013774  ]]
#
#  [[1.2231405  1.2534435  0.98898065 0.8347107  0.7107438  0.8292011
#    0.8622589  0.79063356 0.8677685  0.98347104 1.013774   1.1873279 ]]
#
#  [[1.2534435  0.98898065 0.8347107  0.7107438  0.8292011  0.8622589
#    0.79063356 0.8677685  0.98347104 1.013774   1.1873279  1.4269972 ]]
#
#  [[0.98898065 0.8347107  0.7107438  0.8292011  0.8622589  0.79063356
#    0.8677685  0.98347104 1.013774   1.1873279  1.4269972  1.3829201 ]]
#
#  [[0.8347107  0.7107438  0.8292011  0.8622589  0.79063356 0.8677685
#    0.98347104 1.013774   1.1873279  1.4269972  1.3829201  1.1129477 ]]
#
#  [[0.7107438  0.8292011  0.8622589  0.79063356 0.8677685  0.98347104
#    1.013774   1.1873279  1.4269972  1.3829201  1.1129477  0.98347104]]]
# [1.2231405  1.2534435  0.98898065 0.8347107  0.7107438  0.8292011
#  0.8622589  0.79063356 0.8677685  0.98347104 1.013774   1.1873279
#  1.4269972  1.3829201  1.1129477  0.98347104 0.78787875]

# %% [markdown]
# ### 1.2 - Build the RNN model (20 Points) ##
#
#
# Build an RNN model with SimpleRNN cell.
#
# **Tasks:**
# 1. Build an RNN model with 1 simple RNN layer and 1 Dense layer.  **(10 Points)**
# 2. Compile the model. **(5 Points)**
# 3. Train the model for **1000** epochs with **batch_size = 10**. **(5 Points)**
#
# **Hints:**
# 1. You may consider **tensorflow.keras.layers.SimpleRNN(unit_size=4)** to specify RNN cells.
# 2. Use loss function = 'mean_squared_error' and select **Adam** optimizer with **learning_rate=0.005** and other default settings.
# 3. After first epoch, the train loss is changed to around **0.0912**.
# 4. The model summary is as follows:
# - Total params: 73
# - Trainable params: 73
# - Non-trainable params: 0

# %%
### Build the RNN Model ###
import keras
from keras.models import Sequential

keras.backend.clear_session()

model = Sequential() # Declare Sequential class and assign it to variable "model"
model.add(keras.layers.SimpleRNN(units=4)) # Add a simple RNN layer with unit_size=4 in the model 
model.add(keras.layers.Dense(units=1)) # Add a following Dense layer with units=1 in the model

# %%
### Compile the RNN Model  ###

opt = keras.optimizers.Adam(learning_rate=0.005)
model.compile(loss='mean_squared_error', optimizer='adam') # model compiled with mean_squared_error loss and adam optimizer

# %%
### Train the RNN Model  ###

model.fit(trainX, trainY, epochs=1000, batch_size = 10, verbose=2) # model fit with epoch=1000, batch_size=10; verbose=2 is optional.
model.summary() # print out model structure with model.summary()
# Out:
# Epoch 1/1000
# 11/11 - 0s - loss: 9.7302e-04 - 34ms/epoch - 3ms/step
# Epoch 2/1000
# 11/11 - 0s - loss: 9.6081e-04 - 34ms/epoch - 3ms/step
# Epoch 3/1000
# 11/11 - 0s - loss: 9.4932e-04 - 34ms/epoch - 3ms/step
# Epoch 4/1000
# 11/11 - 0s - loss: 9.6342e-04 - 35ms/epoch - 3ms/step
# Epoch 5/1000
# 11/11 - 0s - loss: 0.0010 - 32ms/epoch - 3ms/step
# Epoch 6/1000
# 11/11 - 0s - loss: 9.5267e-04 - 35ms/epoch - 3ms/step
# Epoch 7/1000
# 11/11 - 0s - loss: 0.0011 - 34ms/epoch - 3ms/step
# Epoch 8/1000
# 11/11 - 0s - loss: 0.0011 - 33ms/epoch - 3ms/step
# Epoch 9/1000
# 11/11 - 0s - loss: 0.0010 - 40ms/epoch - 4ms/step
# Epoch 10/1000
# 11/11 - 0s - loss: 9.6571e-04 - 33ms/epoch - 3ms/step
# Epoch 11/1000
# 11/11 - 0s - loss: 9.4931e-04 - 43ms/epoch - 4ms/step
# Epoch 12/1000
# 11/11 - 0s - loss: 9.5746e-04 - 32ms/epoch - 3ms/step
# Epoch 13/1000
# 11/11 - 0s - loss: 0.0010 - 34ms/epoch - 3ms/step
# Epoch 14/1000
# 11/11 - 0s - loss: 0.0011 - 35ms/epoch - 3ms/step
# Epoch 15/1000
# 11/11 - 0s - loss: 9.4392e-04 - 33ms/epoch - 3ms/step
# Epoch 16/1000
# 11/11 - 0s - loss: 9.8974e-04 - 34ms/epoch - 3ms/step
# Epoch 17/1000
# 11/11 - 0s - loss: 9.7564e-04 - 36ms/epoch - 3ms/step
# Epoch 18/1000
# 11/11 - 0s - loss: 9.4116e-04 - 47ms/epoch - 4ms/step
# Epoch 19/1000
# 11/11 - 0s - loss: 0.0010 - 32ms/epoch - 3ms/step
# Epoch 20/1000
# 11/11 - 0s - loss: 9.9047e-04 - 32ms/epoch - 3ms/step
# Epoch 21/1000
# 11/11 - 0s - loss: 0.0010 - 33ms/epoch - 3ms/step
# Epoch 22/1000
# 11/11 - 0s - loss: 9.4754e-04 - 34ms/epoch - 3ms/step
# Epoch 23/1000
# 11/11 - 0s - loss: 9.5663e-04 - 33ms/epoch - 3ms/step
# Epoch 24/1000
# 11/11 - 0s - loss: 0.0010 - 33ms/epoch - 3ms/step
# Epoch 25/1000
# 11/11 - 0s - loss: 9.3743e-04 - 32ms/epoch - 3ms/step
# Epoch 26/1000
# 11/11 - 0s - loss: 9.3881e-04 - 33ms/epoch - 3ms/step
# Epoch 27/1000
# 11/11 - 0s - loss: 9.3897e-04 - 33ms/epoch - 3ms/step
# Epoch 28/1000
# 11/11 - 0s - loss: 9.6664e-04 - 51ms/epoch - 5ms/step
# Epoch 29/1000
# 11/11 - 0s - loss: 9.4272e-04 - 31ms/epoch - 3ms/step
# Epoch 30/1000
# 11/11 - 0s - loss: 9.3658e-04 - 34ms/epoch - 3ms/step
# Epoch 31/1000
# 11/11 - 0s - loss: 9.2597e-04 - 37ms/epoch - 3ms/step
# Epoch 32/1000
# 11/11 - 0s - loss: 9.4715e-04 - 32ms/epoch - 3ms/step
# Epoch 33/1000
# 11/11 - 0s - loss: 9.3954e-04 - 35ms/epoch - 3ms/step
# Epoch 34/1000
# 11/11 - 0s - loss: 9.9906e-04 - 38ms/epoch - 3ms/step
# Epoch 35/1000
# 11/11 - 0s - loss: 9.7168e-04 - 34ms/epoch - 3ms/step
# Epoch 36/1000
# 11/11 - 0s - loss: 9.4475e-04 - 34ms/epoch - 3ms/step
# Epoch 37/1000
# 11/11 - 0s - loss: 9.3805e-04 - 35ms/epoch - 3ms/step
# Epoch 38/1000
# 11/11 - 0s - loss: 9.3183e-04 - 38ms/epoch - 3ms/step
# Epoch 39/1000
# 11/11 - 0s - loss: 9.3912e-04 - 34ms/epoch - 3ms/step
# Epoch 40/1000
# 11/11 - 0s - loss: 9.5608e-04 - 47ms/epoch - 4ms/step
# Epoch 41/1000
# 11/11 - 0s - loss: 9.5494e-04 - 32ms/epoch - 3ms/step
# Epoch 42/1000
# 11/11 - 0s - loss: 9.4969e-04 - 41ms/epoch - 4ms/step
# Epoch 43/1000
# 11/11 - 0s - loss: 9.7013e-04 - 33ms/epoch - 3ms/step
# Epoch 44/1000
# 11/11 - 0s - loss: 9.7013e-04 - 34ms/epoch - 3ms/step
# Epoch 45/1000
# 11/11 - 0s - loss: 0.0010 - 32ms/epoch - 3ms/step
# Epoch 46/1000
# 11/11 - 0s - loss: 9.6577e-04 - 33ms/epoch - 3ms/step
# Epoch 47/1000
# 11/11 - 0s - loss: 9.9906e-04 - 34ms/epoch - 3ms/step
# Epoch 48/1000
# 11/11 - 0s - loss: 9.5886e-04 - 35ms/epoch - 3ms/step
# Epoch 49/1000
# 11/11 - 0s - loss: 9.8827e-04 - 34ms/epoch - 3ms/step
# Epoch 50/1000
# 11/11 - 0s - loss: 0.0010 - 36ms/epoch - 3ms/step
# Epoch 51/1000
# 11/11 - 0s - loss: 0.0011 - 36ms/epoch - 3ms/step
# Epoch 52/1000
# 11/11 - 0s - loss: 9.4732e-04 - 34ms/epoch - 3ms/step
# Epoch 53/1000
# 11/11 - 0s - loss: 9.4377e-04 - 32ms/epoch - 3ms/step
# Epoch 54/1000
# 11/11 - 0s - loss: 9.9712e-04 - 36ms/epoch - 3ms/step
# Epoch 55/1000
# 11/11 - 0s - loss: 9.5847e-04 - 34ms/epoch - 3ms/step
# Epoch 56/1000
# 11/11 - 0s - loss: 9.6680e-04 - 32ms/epoch - 3ms/step
# Epoch 57/1000
# 11/11 - 0s - loss: 9.2416e-04 - 32ms/epoch - 3ms/step
# Epoch 58/1000
# 11/11 - 0s - loss: 9.6204e-04 - 34ms/epoch - 3ms/step
# Epoch 59/1000
# 11/11 - 0s - loss: 9.4498e-04 - 33ms/epoch - 3ms/step
# Epoch 60/1000
# 11/11 - 0s - loss: 0.0010 - 34ms/epoch - 3ms/step
# Epoch 61/1000
# 11/11 - 0s - loss: 9.3671e-04 - 36ms/epoch - 3ms/step
# Epoch 62/1000
# 11/11 - 0s - loss: 9.6883e-04 - 35ms/epoch - 3ms/step
# Epoch 63/1000
# 11/11 - 0s - loss: 9.5086e-04 - 36ms/epoch - 3ms/step
# Epoch 64/1000
# 11/11 - 0s - loss: 0.0010 - 44ms/epoch - 4ms/step
# Epoch 65/1000
# 11/11 - 0s - loss: 9.2753e-04 - 31ms/epoch - 3ms/step
# Epoch 66/1000
# 11/11 - 0s - loss: 9.3489e-04 - 34ms/epoch - 3ms/step
# Epoch 67/1000
# 11/11 - 0s - loss: 0.0010 - 31ms/epoch - 3ms/step
# Epoch 68/1000
# 11/11 - 0s - loss: 0.0011 - 38ms/epoch - 3ms/step
# Epoch 69/1000
# 11/11 - 0s - loss: 0.0011 - 31ms/epoch - 3ms/step
# Epoch 70/1000
# 11/11 - 0s - loss: 9.4386e-04 - 34ms/epoch - 3ms/step
# Epoch 71/1000
# 11/11 - 0s - loss: 9.2679e-04 - 32ms/epoch - 3ms/step
# Epoch 72/1000
# 11/11 - 0s - loss: 9.4758e-04 - 35ms/epoch - 3ms/step
# Epoch 73/1000
# 11/11 - 0s - loss: 9.3450e-04 - 35ms/epoch - 3ms/step
# Epoch 74/1000
# 11/11 - 0s - loss: 9.4233e-04 - 33ms/epoch - 3ms/step
# Epoch 75/1000
# 11/11 - 0s - loss: 9.2895e-04 - 31ms/epoch - 3ms/step
# Epoch 76/1000
# 11/11 - 0s - loss: 9.6442e-04 - 44ms/epoch - 4ms/step
# Epoch 77/1000
# 11/11 - 0s - loss: 0.0011 - 34ms/epoch - 3ms/step
# Epoch 78/1000
# 11/11 - 0s - loss: 0.0010 - 33ms/epoch - 3ms/step
# Epoch 79/1000
# 11/11 - 0s - loss: 0.0010 - 34ms/epoch - 3ms/step
# Epoch 80/1000
# 11/11 - 0s - loss: 9.8132e-04 - 34ms/epoch - 3ms/step
# Epoch 81/1000
# 11/11 - 0s - loss: 9.5627e-04 - 33ms/epoch - 3ms/step
# Epoch 82/1000
# 11/11 - 0s - loss: 9.9255e-04 - 34ms/epoch - 3ms/step
# Epoch 83/1000
# 11/11 - 0s - loss: 9.8601e-04 - 34ms/epoch - 3ms/step
# Epoch 84/1000
# 11/11 - 0s - loss: 0.0011 - 33ms/epoch - 3ms/step
# Epoch 85/1000
# 11/11 - 0s - loss: 9.3500e-04 - 34ms/epoch - 3ms/step
# Epoch 86/1000
# 11/11 - 0s - loss: 9.3270e-04 - 35ms/epoch - 3ms/step
# Epoch 87/1000
# 11/11 - 0s - loss: 9.5311e-04 - 33ms/epoch - 3ms/step
# Epoch 88/1000
# 11/11 - 0s - loss: 9.3873e-04 - 34ms/epoch - 3ms/step
# Epoch 89/1000
# 11/11 - 0s - loss: 9.4762e-04 - 32ms/epoch - 3ms/step
# Epoch 90/1000
# 11/11 - 0s - loss: 9.5207e-04 - 33ms/epoch - 3ms/step
# Epoch 91/1000
# 11/11 - 0s - loss: 0.0011 - 40ms/epoch - 4ms/step
# Epoch 92/1000
# 11/11 - 0s - loss: 9.3428e-04 - 34ms/epoch - 3ms/step
# Epoch 93/1000
# 11/11 - 0s - loss: 9.3213e-04 - 31ms/epoch - 3ms/step
# Epoch 94/1000
# 11/11 - 0s - loss: 9.2718e-04 - 34ms/epoch - 3ms/step
# Epoch 95/1000
# 11/11 - 0s - loss: 9.6402e-04 - 35ms/epoch - 3ms/step
# Epoch 96/1000
# 11/11 - 0s - loss: 9.4436e-04 - 36ms/epoch - 3ms/step
# Epoch 97/1000
# 11/11 - 0s - loss: 9.3831e-04 - 33ms/epoch - 3ms/step
# Epoch 98/1000
# 11/11 - 0s - loss: 9.2562e-04 - 35ms/epoch - 3ms/step
# Epoch 99/1000
# 11/11 - 0s - loss: 9.6272e-04 - 32ms/epoch - 3ms/step
# Epoch 100/1000
# 11/11 - 0s - loss: 9.2671e-04 - 36ms/epoch - 3ms/step
# Epoch 101/1000
# 11/11 - 0s - loss: 9.4370e-04 - 38ms/epoch - 3ms/step
# Epoch 102/1000
# 11/11 - 0s - loss: 9.2220e-04 - 35ms/epoch - 3ms/step
# Epoch 103/1000
# 11/11 - 0s - loss: 9.3956e-04 - 37ms/epoch - 3ms/step
# Epoch 104/1000
# 11/11 - 0s - loss: 0.0010 - 34ms/epoch - 3ms/step
# Epoch 105/1000
# 11/11 - 0s - loss: 9.7416e-04 - 40ms/epoch - 4ms/step
# Epoch 106/1000
# 11/11 - 0s - loss: 9.6167e-04 - 33ms/epoch - 3ms/step
# Epoch 107/1000
# 11/11 - 0s - loss: 0.0010 - 32ms/epoch - 3ms/step
# Epoch 108/1000
# 11/11 - 0s - loss: 9.6251e-04 - 32ms/epoch - 3ms/step
# Epoch 109/1000
# 11/11 - 0s - loss: 0.0010 - 37ms/epoch - 3ms/step
# Epoch 110/1000
# 11/11 - 0s - loss: 9.5875e-04 - 36ms/epoch - 3ms/step
# Epoch 111/1000
# 11/11 - 0s - loss: 9.4010e-04 - 38ms/epoch - 3ms/step
# Epoch 112/1000
# 11/11 - 0s - loss: 9.3807e-04 - 34ms/epoch - 3ms/step
# Epoch 113/1000
# 11/11 - 0s - loss: 9.5593e-04 - 38ms/epoch - 3ms/step
# Epoch 114/1000
# 11/11 - 0s - loss: 9.2697e-04 - 32ms/epoch - 3ms/step
# Epoch 115/1000
# 11/11 - 0s - loss: 9.4181e-04 - 37ms/epoch - 3ms/step
# Epoch 116/1000
# 11/11 - 0s - loss: 9.3117e-04 - 37ms/epoch - 3ms/step
# Epoch 117/1000
# 11/11 - 0s - loss: 9.4361e-04 - 50ms/epoch - 5ms/step
# Epoch 118/1000
# 11/11 - 0s - loss: 9.6715e-04 - 36ms/epoch - 3ms/step
# Epoch 119/1000
# 11/11 - 0s - loss: 9.5548e-04 - 32ms/epoch - 3ms/step
# Epoch 120/1000
# 11/11 - 0s - loss: 9.4119e-04 - 33ms/epoch - 3ms/step
# Epoch 121/1000
# 11/11 - 0s - loss: 9.4430e-04 - 36ms/epoch - 3ms/step
# Epoch 122/1000
# 11/11 - 0s - loss: 9.6087e-04 - 36ms/epoch - 3ms/step
# Epoch 123/1000
# 11/11 - 0s - loss: 9.8431e-04 - 33ms/epoch - 3ms/step
# Epoch 124/1000
# 11/11 - 0s - loss: 9.3391e-04 - 34ms/epoch - 3ms/step
# Epoch 125/1000
# 11/11 - 0s - loss: 9.6782e-04 - 35ms/epoch - 3ms/step
# Epoch 126/1000
# 11/11 - 0s - loss: 0.0010 - 38ms/epoch - 3ms/step
# Epoch 127/1000
# 11/11 - 0s - loss: 0.0010 - 36ms/epoch - 3ms/step
# Epoch 128/1000
# 11/11 - 0s - loss: 9.8464e-04 - 35ms/epoch - 3ms/step
# Epoch 129/1000
# 11/11 - 0s - loss: 0.0011 - 33ms/epoch - 3ms/step
# Epoch 130/1000
# 11/11 - 0s - loss: 9.4518e-04 - 43ms/epoch - 4ms/step
# Epoch 131/1000
# 11/11 - 0s - loss: 9.3296e-04 - 33ms/epoch - 3ms/step
# Epoch 132/1000
# 11/11 - 0s - loss: 9.2909e-04 - 34ms/epoch - 3ms/step
# Epoch 133/1000
# 11/11 - 0s - loss: 0.0010 - 35ms/epoch - 3ms/step
# Epoch 134/1000
# 11/11 - 0s - loss: 9.6355e-04 - 33ms/epoch - 3ms/step
# Epoch 135/1000
# 11/11 - 0s - loss: 9.8712e-04 - 35ms/epoch - 3ms/step
# Epoch 136/1000
# 11/11 - 0s - loss: 9.2868e-04 - 35ms/epoch - 3ms/step
# Epoch 137/1000
# 11/11 - 0s - loss: 0.0011 - 34ms/epoch - 3ms/step
# Epoch 138/1000
# 11/11 - 0s - loss: 9.7327e-04 - 33ms/epoch - 3ms/step
# Epoch 139/1000
# 11/11 - 0s - loss: 9.2341e-04 - 33ms/epoch - 3ms/step
# Epoch 140/1000
# 11/11 - 0s - loss: 9.3024e-04 - 35ms/epoch - 3ms/step
# Epoch 141/1000
# 11/11 - 0s - loss: 9.8781e-04 - 37ms/epoch - 3ms/step
# Epoch 142/1000
# 11/11 - 0s - loss: 0.0010 - 34ms/epoch - 3ms/step
# Epoch 143/1000
# 11/11 - 0s - loss: 9.6172e-04 - 44ms/epoch - 4ms/step
# Epoch 144/1000
# 11/11 - 0s - loss: 9.3940e-04 - 37ms/epoch - 3ms/step
# Epoch 145/1000
# 11/11 - 0s - loss: 0.0010 - 33ms/epoch - 3ms/step
# Epoch 146/1000
# 11/11 - 0s - loss: 9.6135e-04 - 33ms/epoch - 3ms/step
# Epoch 147/1000
# 11/11 - 0s - loss: 9.3907e-04 - 35ms/epoch - 3ms/step
# Epoch 148/1000
# 11/11 - 0s - loss: 9.4299e-04 - 32ms/epoch - 3ms/step
# Epoch 149/1000
# 11/11 - 0s - loss: 0.0011 - 35ms/epoch - 3ms/step
# Epoch 150/1000
# 11/11 - 0s - loss: 0.0011 - 37ms/epoch - 3ms/step
# Epoch 151/1000
# 11/11 - 0s - loss: 9.3714e-04 - 33ms/epoch - 3ms/step
# Epoch 152/1000
# 11/11 - 0s - loss: 9.8915e-04 - 32ms/epoch - 3ms/step
# Epoch 153/1000
# 11/11 - 0s - loss: 9.3825e-04 - 32ms/epoch - 3ms/step
# Epoch 154/1000
# 11/11 - 0s - loss: 9.4631e-04 - 34ms/epoch - 3ms/step
# Epoch 155/1000
# 11/11 - 0s - loss: 9.5520e-04 - 36ms/epoch - 3ms/step
# Epoch 156/1000
# 11/11 - 0s - loss: 9.3496e-04 - 33ms/epoch - 3ms/step
# Epoch 157/1000
# 11/11 - 0s - loss: 9.2619e-04 - 33ms/epoch - 3ms/step
# Epoch 158/1000
# 11/11 - 0s - loss: 9.6813e-04 - 36ms/epoch - 3ms/step
# Epoch 159/1000
# 11/11 - 0s - loss: 9.4072e-04 - 33ms/epoch - 3ms/step
# Epoch 160/1000
# 11/11 - 0s - loss: 9.3636e-04 - 37ms/epoch - 3ms/step
# Epoch 161/1000
# 11/11 - 0s - loss: 9.5707e-04 - 33ms/epoch - 3ms/step
# Epoch 162/1000
# 11/11 - 0s - loss: 0.0014 - 34ms/epoch - 3ms/step
# Epoch 163/1000
# 11/11 - 0s - loss: 0.0010 - 35ms/epoch - 3ms/step
# Epoch 164/1000
# 11/11 - 0s - loss: 9.6248e-04 - 33ms/epoch - 3ms/step
# Epoch 165/1000
# 11/11 - 0s - loss: 9.4389e-04 - 33ms/epoch - 3ms/step
# Epoch 166/1000
# 11/11 - 0s - loss: 9.2959e-04 - 37ms/epoch - 3ms/step
# Epoch 167/1000
# 11/11 - 0s - loss: 9.2898e-04 - 34ms/epoch - 3ms/step
# Epoch 168/1000
# 11/11 - 0s - loss: 9.5074e-04 - 33ms/epoch - 3ms/step
# Epoch 169/1000
# 11/11 - 0s - loss: 9.2517e-04 - 43ms/epoch - 4ms/step
# Epoch 170/1000
# 11/11 - 0s - loss: 9.5265e-04 - 35ms/epoch - 3ms/step
# Epoch 171/1000
# 11/11 - 0s - loss: 9.3226e-04 - 32ms/epoch - 3ms/step
# Epoch 172/1000
# 11/11 - 0s - loss: 0.0011 - 33ms/epoch - 3ms/step
# Epoch 173/1000
# 11/11 - 0s - loss: 9.9807e-04 - 36ms/epoch - 3ms/step
# Epoch 174/1000
# 11/11 - 0s - loss: 9.5004e-04 - 34ms/epoch - 3ms/step
# Epoch 175/1000
# 11/11 - 0s - loss: 9.4095e-04 - 33ms/epoch - 3ms/step
# Epoch 176/1000
# 11/11 - 0s - loss: 9.6470e-04 - 33ms/epoch - 3ms/step
# Epoch 177/1000
# 11/11 - 0s - loss: 0.0011 - 39ms/epoch - 4ms/step
# Epoch 178/1000
# 11/11 - 0s - loss: 9.4198e-04 - 35ms/epoch - 3ms/step
# Epoch 179/1000
# 11/11 - 0s - loss: 9.4107e-04 - 36ms/epoch - 3ms/step
# Epoch 180/1000
# 11/11 - 0s - loss: 9.3424e-04 - 33ms/epoch - 3ms/step
# Epoch 181/1000
# 11/11 - 0s - loss: 9.6431e-04 - 35ms/epoch - 3ms/step
# Epoch 182/1000
# 11/11 - 0s - loss: 9.6401e-04 - 35ms/epoch - 3ms/step
# Epoch 183/1000
# 11/11 - 0s - loss: 9.5527e-04 - 35ms/epoch - 3ms/step
# Epoch 184/1000
# 11/11 - 0s - loss: 9.3938e-04 - 33ms/epoch - 3ms/step
# Epoch 185/1000
# 11/11 - 0s - loss: 9.3581e-04 - 34ms/epoch - 3ms/step
# Epoch 186/1000
# 11/11 - 0s - loss: 9.5816e-04 - 32ms/epoch - 3ms/step
# Epoch 187/1000
# 11/11 - 0s - loss: 9.8465e-04 - 35ms/epoch - 3ms/step
# Epoch 188/1000
# 11/11 - 0s - loss: 0.0010 - 39ms/epoch - 4ms/step
# Epoch 189/1000
# 11/11 - 0s - loss: 9.2861e-04 - 34ms/epoch - 3ms/step
# Epoch 190/1000
# 11/11 - 0s - loss: 0.0010 - 35ms/epoch - 3ms/step
# Epoch 191/1000
# 11/11 - 0s - loss: 9.4715e-04 - 33ms/epoch - 3ms/step
# Epoch 192/1000
# 11/11 - 0s - loss: 9.4130e-04 - 34ms/epoch - 3ms/step
# Epoch 193/1000
# 11/11 - 0s - loss: 0.0011 - 36ms/epoch - 3ms/step
# Epoch 194/1000
# 11/11 - 0s - loss: 9.8718e-04 - 38ms/epoch - 3ms/step
# Epoch 195/1000
# 11/11 - 0s - loss: 9.2819e-04 - 33ms/epoch - 3ms/step
# Epoch 196/1000
# 11/11 - 0s - loss: 9.5419e-04 - 43ms/epoch - 4ms/step
# Epoch 197/1000
# 11/11 - 0s - loss: 9.3230e-04 - 34ms/epoch - 3ms/step
# Epoch 198/1000
# 11/11 - 0s - loss: 9.2131e-04 - 59ms/epoch - 5ms/step
# Epoch 199/1000
# 11/11 - 0s - loss: 9.1980e-04 - 54ms/epoch - 5ms/step
# Epoch 200/1000
# 11/11 - 0s - loss: 0.0011 - 54ms/epoch - 5ms/step
# Epoch 201/1000
# 11/11 - 0s - loss: 9.3130e-04 - 54ms/epoch - 5ms/step
# Epoch 202/1000
# 11/11 - 0s - loss: 9.5833e-04 - 55ms/epoch - 5ms/step
# Epoch 203/1000
# 11/11 - 0s - loss: 9.6007e-04 - 57ms/epoch - 5ms/step
# Epoch 204/1000
# 11/11 - 0s - loss: 9.9718e-04 - 58ms/epoch - 5ms/step
# Epoch 205/1000
# 11/11 - 0s - loss: 9.3858e-04 - 52ms/epoch - 5ms/step
# Epoch 206/1000
# 11/11 - 0s - loss: 9.3362e-04 - 51ms/epoch - 5ms/step
# Epoch 207/1000
# 11/11 - 0s - loss: 9.3942e-04 - 54ms/epoch - 5ms/step
# Epoch 208/1000
# 11/11 - 0s - loss: 9.2140e-04 - 56ms/epoch - 5ms/step
# Epoch 209/1000
# 11/11 - 0s - loss: 9.3667e-04 - 52ms/epoch - 5ms/step
# Epoch 210/1000
# 11/11 - 0s - loss: 0.0010 - 51ms/epoch - 5ms/step
# Epoch 211/1000
# 11/11 - 0s - loss: 9.1952e-04 - 62ms/epoch - 6ms/step
# Epoch 212/1000
# 11/11 - 0s - loss: 9.4934e-04 - 50ms/epoch - 5ms/step
# Epoch 213/1000
# 11/11 - 0s - loss: 9.2605e-04 - 55ms/epoch - 5ms/step
# Epoch 214/1000
# 11/11 - 0s - loss: 9.3859e-04 - 56ms/epoch - 5ms/step
# Epoch 215/1000
# 11/11 - 0s - loss: 9.7221e-04 - 58ms/epoch - 5ms/step
# Epoch 216/1000
# 11/11 - 0s - loss: 9.4791e-04 - 52ms/epoch - 5ms/step
# Epoch 217/1000
# 11/11 - 0s - loss: 9.3272e-04 - 54ms/epoch - 5ms/step
# Epoch 218/1000
# 11/11 - 0s - loss: 0.0011 - 53ms/epoch - 5ms/step
# Epoch 219/1000
# 11/11 - 0s - loss: 9.4170e-04 - 57ms/epoch - 5ms/step
# Epoch 220/1000
# 11/11 - 0s - loss: 9.3593e-04 - 54ms/epoch - 5ms/step
# Epoch 221/1000
# 11/11 - 0s - loss: 9.4227e-04 - 54ms/epoch - 5ms/step
# Epoch 222/1000
# 11/11 - 0s - loss: 9.8071e-04 - 42ms/epoch - 4ms/step
# Epoch 223/1000
# 11/11 - 0s - loss: 0.0010 - 42ms/epoch - 4ms/step
# Epoch 224/1000
# 11/11 - 0s - loss: 9.2412e-04 - 58ms/epoch - 5ms/step
# Epoch 225/1000
# 11/11 - 0s - loss: 9.7902e-04 - 53ms/epoch - 5ms/step
# Epoch 226/1000
# 11/11 - 0s - loss: 0.0010 - 54ms/epoch - 5ms/step
# Epoch 227/1000
# 11/11 - 0s - loss: 9.9525e-04 - 50ms/epoch - 5ms/step
# Epoch 228/1000
# 11/11 - 0s - loss: 9.4315e-04 - 52ms/epoch - 5ms/step
# Epoch 229/1000
# 11/11 - 0s - loss: 9.7828e-04 - 54ms/epoch - 5ms/step
# Epoch 230/1000
# 11/11 - 0s - loss: 9.2371e-04 - 54ms/epoch - 5ms/step
# Epoch 231/1000
# 11/11 - 0s - loss: 9.2481e-04 - 58ms/epoch - 5ms/step
# Epoch 232/1000
# 11/11 - 0s - loss: 9.5315e-04 - 56ms/epoch - 5ms/step
# Epoch 233/1000
# 11/11 - 0s - loss: 9.2352e-04 - 54ms/epoch - 5ms/step
# Epoch 234/1000
# 11/11 - 0s - loss: 9.1979e-04 - 55ms/epoch - 5ms/step
# Epoch 235/1000
# 11/11 - 0s - loss: 0.0010 - 55ms/epoch - 5ms/step
# Epoch 236/1000
# 11/11 - 0s - loss: 9.5486e-04 - 56ms/epoch - 5ms/step
# Epoch 237/1000
# 11/11 - 0s - loss: 9.3140e-04 - 53ms/epoch - 5ms/step
# Epoch 238/1000
# 11/11 - 0s - loss: 9.4836e-04 - 54ms/epoch - 5ms/step
# Epoch 239/1000
# 11/11 - 0s - loss: 0.0012 - 59ms/epoch - 5ms/step
# Epoch 240/1000
# 11/11 - 0s - loss: 9.2431e-04 - 53ms/epoch - 5ms/step
# Epoch 241/1000
# 11/11 - 0s - loss: 9.1893e-04 - 55ms/epoch - 5ms/step
# Epoch 242/1000
# 11/11 - 0s - loss: 9.7183e-04 - 67ms/epoch - 6ms/step
# Epoch 243/1000
# 11/11 - 0s - loss: 9.4440e-04 - 58ms/epoch - 5ms/step
# Epoch 244/1000
# 11/11 - 0s - loss: 9.4443e-04 - 56ms/epoch - 5ms/step
# Epoch 245/1000
# 11/11 - 0s - loss: 9.1966e-04 - 56ms/epoch - 5ms/step
# Epoch 246/1000
# 11/11 - 0s - loss: 9.1714e-04 - 55ms/epoch - 5ms/step
# Epoch 247/1000
# 11/11 - 0s - loss: 9.7756e-04 - 51ms/epoch - 5ms/step
# Epoch 248/1000
# 11/11 - 0s - loss: 9.6019e-04 - 56ms/epoch - 5ms/step
# Epoch 249/1000
# 11/11 - 0s - loss: 9.9198e-04 - 64ms/epoch - 6ms/step
# Epoch 250/1000
# 11/11 - 0s - loss: 9.5252e-04 - 52ms/epoch - 5ms/step
# Epoch 251/1000
# 11/11 - 0s - loss: 9.5488e-04 - 64ms/epoch - 6ms/step
# Epoch 252/1000
# 11/11 - 0s - loss: 9.1081e-04 - 52ms/epoch - 5ms/step
# Epoch 253/1000
# 11/11 - 0s - loss: 9.1590e-04 - 57ms/epoch - 5ms/step
# Epoch 254/1000
# 11/11 - 0s - loss: 9.1388e-04 - 53ms/epoch - 5ms/step
# Epoch 255/1000
# 11/11 - 0s - loss: 0.0010 - 51ms/epoch - 5ms/step
# Epoch 256/1000
# 11/11 - 0s - loss: 0.0010 - 47ms/epoch - 4ms/step
# Epoch 257/1000
# 11/11 - 0s - loss: 9.2300e-04 - 36ms/epoch - 3ms/step
# Epoch 258/1000
# 11/11 - 0s - loss: 9.3264e-04 - 35ms/epoch - 3ms/step
# Epoch 259/1000
# 11/11 - 0s - loss: 9.4159e-04 - 32ms/epoch - 3ms/step
# Epoch 260/1000
# 11/11 - 0s - loss: 9.4803e-04 - 33ms/epoch - 3ms/step
# Epoch 261/1000
# 11/11 - 0s - loss: 9.3852e-04 - 36ms/epoch - 3ms/step
# Epoch 262/1000
# 11/11 - 0s - loss: 9.5387e-04 - 35ms/epoch - 3ms/step
# Epoch 263/1000
# 11/11 - 0s - loss: 9.3122e-04 - 38ms/epoch - 3ms/step
# Epoch 264/1000
# 11/11 - 0s - loss: 9.1460e-04 - 34ms/epoch - 3ms/step
# Epoch 265/1000
# 11/11 - 0s - loss: 9.4429e-04 - 34ms/epoch - 3ms/step
# Epoch 266/1000
# 11/11 - 0s - loss: 9.4338e-04 - 35ms/epoch - 3ms/step
# Epoch 267/1000
# 11/11 - 0s - loss: 9.6063e-04 - 34ms/epoch - 3ms/step
# Epoch 268/1000
# 11/11 - 0s - loss: 0.0012 - 38ms/epoch - 3ms/step
# Epoch 269/1000
# 11/11 - 0s - loss: 9.3496e-04 - 34ms/epoch - 3ms/step
# Epoch 270/1000
# 11/11 - 0s - loss: 9.3085e-04 - 36ms/epoch - 3ms/step
# Epoch 271/1000
# 11/11 - 0s - loss: 9.4735e-04 - 44ms/epoch - 4ms/step
# Epoch 272/1000
# 11/11 - 0s - loss: 9.4676e-04 - 35ms/epoch - 3ms/step
# Epoch 273/1000
# 11/11 - 0s - loss: 0.0010 - 37ms/epoch - 3ms/step
# Epoch 274/1000
# 11/11 - 0s - loss: 9.1602e-04 - 35ms/epoch - 3ms/step
# Epoch 275/1000
# 11/11 - 0s - loss: 9.4945e-04 - 34ms/epoch - 3ms/step
# Epoch 276/1000
# 11/11 - 0s - loss: 9.5633e-04 - 40ms/epoch - 4ms/step
# Epoch 277/1000
# 11/11 - 0s - loss: 9.6339e-04 - 51ms/epoch - 5ms/step
# Epoch 278/1000
# 11/11 - 0s - loss: 9.2525e-04 - 36ms/epoch - 3ms/step
# Epoch 279/1000
# 11/11 - 0s - loss: 9.1422e-04 - 35ms/epoch - 3ms/step
# Epoch 280/1000
# 11/11 - 0s - loss: 9.8937e-04 - 33ms/epoch - 3ms/step
# Epoch 281/1000
# 11/11 - 0s - loss: 9.7307e-04 - 34ms/epoch - 3ms/step
# Epoch 282/1000
# 11/11 - 0s - loss: 9.4752e-04 - 40ms/epoch - 4ms/step
# Epoch 283/1000
# 11/11 - 0s - loss: 9.3175e-04 - 36ms/epoch - 3ms/step
# Epoch 284/1000
# 11/11 - 0s - loss: 0.0011 - 32ms/epoch - 3ms/step
# Epoch 285/1000
# 11/11 - 0s - loss: 9.2919e-04 - 35ms/epoch - 3ms/step
# Epoch 286/1000
# 11/11 - 0s - loss: 9.5069e-04 - 34ms/epoch - 3ms/step
# Epoch 287/1000
# 11/11 - 0s - loss: 9.7083e-04 - 33ms/epoch - 3ms/step
# Epoch 288/1000
# 11/11 - 0s - loss: 9.2557e-04 - 32ms/epoch - 3ms/step
# Epoch 289/1000
# 11/11 - 0s - loss: 0.0012 - 38ms/epoch - 3ms/step
# Epoch 290/1000
# 11/11 - 0s - loss: 9.9332e-04 - 33ms/epoch - 3ms/step
# Epoch 291/1000
# 11/11 - 0s - loss: 9.2610e-04 - 37ms/epoch - 3ms/step
# Epoch 292/1000
# 11/11 - 0s - loss: 9.2924e-04 - 33ms/epoch - 3ms/step
# Epoch 293/1000
# 11/11 - 0s - loss: 9.1940e-04 - 35ms/epoch - 3ms/step
# Epoch 294/1000
# 11/11 - 0s - loss: 9.3244e-04 - 32ms/epoch - 3ms/step
# Epoch 295/1000
# 11/11 - 0s - loss: 9.8233e-04 - 37ms/epoch - 3ms/step
# Epoch 296/1000
# 11/11 - 0s - loss: 9.3092e-04 - 33ms/epoch - 3ms/step
# Epoch 297/1000
# 11/11 - 0s - loss: 9.4400e-04 - 43ms/epoch - 4ms/step
# Epoch 298/1000
# 11/11 - 0s - loss: 9.9467e-04 - 34ms/epoch - 3ms/step
# Epoch 299/1000
# 11/11 - 0s - loss: 0.0014 - 43ms/epoch - 4ms/step
# Epoch 300/1000
# 11/11 - 0s - loss: 0.0010 - 35ms/epoch - 3ms/step
# Epoch 301/1000
# 11/11 - 0s - loss: 9.4720e-04 - 34ms/epoch - 3ms/step
# Epoch 302/1000
# 11/11 - 0s - loss: 9.5055e-04 - 37ms/epoch - 3ms/step
# Epoch 303/1000
# 11/11 - 0s - loss: 9.2407e-04 - 35ms/epoch - 3ms/step
# Epoch 304/1000
# 11/11 - 0s - loss: 9.2112e-04 - 37ms/epoch - 3ms/step
# Epoch 305/1000
# 11/11 - 0s - loss: 9.4023e-04 - 33ms/epoch - 3ms/step
# Epoch 306/1000
# 11/11 - 0s - loss: 9.8141e-04 - 33ms/epoch - 3ms/step
# Epoch 307/1000
# 11/11 - 0s - loss: 9.4520e-04 - 35ms/epoch - 3ms/step
# Epoch 308/1000
# 11/11 - 0s - loss: 9.6169e-04 - 33ms/epoch - 3ms/step
# Epoch 309/1000
# 11/11 - 0s - loss: 9.4808e-04 - 38ms/epoch - 3ms/step
# Epoch 310/1000
# 11/11 - 0s - loss: 9.1947e-04 - 42ms/epoch - 4ms/step
# Epoch 311/1000
# 11/11 - 0s - loss: 9.7839e-04 - 39ms/epoch - 4ms/step
# Epoch 312/1000
# 11/11 - 0s - loss: 9.5541e-04 - 33ms/epoch - 3ms/step
# Epoch 313/1000
# 11/11 - 0s - loss: 9.2139e-04 - 34ms/epoch - 3ms/step
# Epoch 314/1000
# 11/11 - 0s - loss: 9.3326e-04 - 33ms/epoch - 3ms/step
# Epoch 315/1000
# 11/11 - 0s - loss: 9.1491e-04 - 32ms/epoch - 3ms/step
# Epoch 316/1000
# 11/11 - 0s - loss: 9.5447e-04 - 33ms/epoch - 3ms/step
# Epoch 317/1000
# 11/11 - 0s - loss: 9.2477e-04 - 40ms/epoch - 4ms/step
# Epoch 318/1000
# 11/11 - 0s - loss: 9.0746e-04 - 33ms/epoch - 3ms/step
# Epoch 319/1000
# 11/11 - 0s - loss: 9.1061e-04 - 34ms/epoch - 3ms/step
# Epoch 320/1000
# 11/11 - 0s - loss: 9.2121e-04 - 36ms/epoch - 3ms/step
# Epoch 321/1000
# 11/11 - 0s - loss: 0.0012 - 32ms/epoch - 3ms/step
# Epoch 322/1000
# 11/11 - 0s - loss: 9.7346e-04 - 42ms/epoch - 4ms/step
# Epoch 323/1000
# 11/11 - 0s - loss: 9.2409e-04 - 37ms/epoch - 3ms/step
# Epoch 324/1000
# 11/11 - 0s - loss: 9.2068e-04 - 39ms/epoch - 4ms/step
# Epoch 325/1000
# 11/11 - 0s - loss: 9.1559e-04 - 37ms/epoch - 3ms/step
# Epoch 326/1000
# 11/11 - 0s - loss: 9.1356e-04 - 32ms/epoch - 3ms/step
# Epoch 327/1000
# 11/11 - 0s - loss: 9.2952e-04 - 36ms/epoch - 3ms/step
# Epoch 328/1000
# 11/11 - 0s - loss: 9.5083e-04 - 33ms/epoch - 3ms/step
# Epoch 329/1000
# 11/11 - 0s - loss: 9.5610e-04 - 34ms/epoch - 3ms/step
# Epoch 330/1000
# 11/11 - 0s - loss: 9.2474e-04 - 34ms/epoch - 3ms/step
# Epoch 331/1000
# 11/11 - 0s - loss: 9.3121e-04 - 32ms/epoch - 3ms/step
# Epoch 332/1000
# 11/11 - 0s - loss: 9.2484e-04 - 35ms/epoch - 3ms/step
# Epoch 333/1000
# 11/11 - 0s - loss: 9.1196e-04 - 35ms/epoch - 3ms/step
# Epoch 334/1000
# 11/11 - 0s - loss: 0.0011 - 36ms/epoch - 3ms/step
# Epoch 335/1000
# 11/11 - 0s - loss: 0.0012 - 34ms/epoch - 3ms/step
# Epoch 336/1000
# 11/11 - 0s - loss: 9.5026e-04 - 32ms/epoch - 3ms/step
# Epoch 337/1000
# 11/11 - 0s - loss: 9.1846e-04 - 35ms/epoch - 3ms/step
# Epoch 338/1000
# 11/11 - 0s - loss: 0.0012 - 34ms/epoch - 3ms/step
# Epoch 339/1000
# 11/11 - 0s - loss: 9.2146e-04 - 35ms/epoch - 3ms/step
# Epoch 340/1000
# 11/11 - 0s - loss: 9.3333e-04 - 33ms/epoch - 3ms/step
# Epoch 341/1000
# 11/11 - 0s - loss: 9.1904e-04 - 36ms/epoch - 3ms/step
# Epoch 342/1000
# 11/11 - 0s - loss: 9.1215e-04 - 31ms/epoch - 3ms/step
# Epoch 343/1000
# 11/11 - 0s - loss: 9.2385e-04 - 32ms/epoch - 3ms/step
# Epoch 344/1000
# 11/11 - 0s - loss: 0.0011 - 34ms/epoch - 3ms/step
# Epoch 345/1000
# 11/11 - 0s - loss: 9.9726e-04 - 33ms/epoch - 3ms/step
# Epoch 346/1000
# 11/11 - 0s - loss: 0.0011 - 35ms/epoch - 3ms/step
# Epoch 347/1000
# 11/11 - 0s - loss: 0.0010 - 33ms/epoch - 3ms/step
# Epoch 348/1000
# 11/11 - 0s - loss: 9.2371e-04 - 37ms/epoch - 3ms/step
# Epoch 349/1000
# 11/11 - 0s - loss: 9.2184e-04 - 43ms/epoch - 4ms/step
# Epoch 350/1000
# 11/11 - 0s - loss: 0.0010 - 34ms/epoch - 3ms/step
# Epoch 351/1000
# 11/11 - 0s - loss: 9.1032e-04 - 34ms/epoch - 3ms/step
# Epoch 352/1000
# 11/11 - 0s - loss: 9.5049e-04 - 34ms/epoch - 3ms/step
# Epoch 353/1000
# 11/11 - 0s - loss: 9.5315e-04 - 35ms/epoch - 3ms/step
# Epoch 354/1000
# 11/11 - 0s - loss: 9.4288e-04 - 33ms/epoch - 3ms/step
# Epoch 355/1000
# 11/11 - 0s - loss: 9.5517e-04 - 35ms/epoch - 3ms/step
# Epoch 356/1000
# 11/11 - 0s - loss: 9.4026e-04 - 34ms/epoch - 3ms/step
# Epoch 357/1000
# 11/11 - 0s - loss: 9.8849e-04 - 35ms/epoch - 3ms/step
# Epoch 358/1000
# 11/11 - 0s - loss: 9.4873e-04 - 34ms/epoch - 3ms/step
# Epoch 359/1000
# 11/11 - 0s - loss: 9.9308e-04 - 35ms/epoch - 3ms/step
# Epoch 360/1000
# 11/11 - 0s - loss: 9.4954e-04 - 33ms/epoch - 3ms/step
# Epoch 361/1000
# 11/11 - 0s - loss: 9.1840e-04 - 34ms/epoch - 3ms/step
# Epoch 362/1000
# 11/11 - 0s - loss: 9.1810e-04 - 35ms/epoch - 3ms/step
# Epoch 363/1000
# 11/11 - 0s - loss: 9.0980e-04 - 32ms/epoch - 3ms/step
# Epoch 364/1000
# 11/11 - 0s - loss: 9.2085e-04 - 35ms/epoch - 3ms/step
# Epoch 365/1000
# 11/11 - 0s - loss: 9.3973e-04 - 31ms/epoch - 3ms/step
# Epoch 366/1000
# 11/11 - 0s - loss: 9.8930e-04 - 31ms/epoch - 3ms/step
# Epoch 367/1000
# 11/11 - 0s - loss: 9.6515e-04 - 37ms/epoch - 3ms/step
# Epoch 368/1000
# 11/11 - 0s - loss: 0.0013 - 35ms/epoch - 3ms/step
# Epoch 369/1000
# 11/11 - 0s - loss: 9.1602e-04 - 34ms/epoch - 3ms/step
# Epoch 370/1000
# 11/11 - 0s - loss: 9.5665e-04 - 35ms/epoch - 3ms/step
# Epoch 371/1000
# 11/11 - 0s - loss: 0.0010 - 36ms/epoch - 3ms/step
# Epoch 372/1000
# 11/11 - 0s - loss: 0.0010 - 37ms/epoch - 3ms/step
# Epoch 373/1000
# 11/11 - 0s - loss: 9.1655e-04 - 34ms/epoch - 3ms/step
# Epoch 374/1000
# 11/11 - 0s - loss: 0.0010 - 35ms/epoch - 3ms/step
# Epoch 375/1000
# 11/11 - 0s - loss: 9.6871e-04 - 43ms/epoch - 4ms/step
# Epoch 376/1000
# 11/11 - 0s - loss: 9.7295e-04 - 33ms/epoch - 3ms/step
# Epoch 377/1000
# 11/11 - 0s - loss: 9.2305e-04 - 34ms/epoch - 3ms/step
# Epoch 378/1000
# 11/11 - 0s - loss: 0.0011 - 34ms/epoch - 3ms/step
# Epoch 379/1000
# 11/11 - 0s - loss: 9.3964e-04 - 34ms/epoch - 3ms/step
# Epoch 380/1000
# 11/11 - 0s - loss: 0.0010 - 31ms/epoch - 3ms/step
# Epoch 381/1000
# 11/11 - 0s - loss: 0.0011 - 36ms/epoch - 3ms/step
# Epoch 382/1000
# 11/11 - 0s - loss: 9.2011e-04 - 34ms/epoch - 3ms/step
# Epoch 383/1000
# 11/11 - 0s - loss: 9.0082e-04 - 33ms/epoch - 3ms/step
# Epoch 384/1000
# 11/11 - 0s - loss: 9.0406e-04 - 32ms/epoch - 3ms/step
# Epoch 385/1000
# 11/11 - 0s - loss: 9.2965e-04 - 33ms/epoch - 3ms/step
# Epoch 386/1000
# 11/11 - 0s - loss: 9.2187e-04 - 34ms/epoch - 3ms/step
# Epoch 387/1000
# 11/11 - 0s - loss: 9.4180e-04 - 32ms/epoch - 3ms/step
# Epoch 388/1000
# 11/11 - 0s - loss: 9.0871e-04 - 35ms/epoch - 3ms/step
# Epoch 389/1000
# 11/11 - 0s - loss: 0.0010 - 71ms/epoch - 6ms/step
# Epoch 390/1000
# 11/11 - 0s - loss: 0.0010 - 52ms/epoch - 5ms/step
# Epoch 391/1000
# 11/11 - 0s - loss: 0.0011 - 61ms/epoch - 6ms/step
# Epoch 392/1000
# 11/11 - 0s - loss: 9.1304e-04 - 67ms/epoch - 6ms/step
# Epoch 393/1000
# 11/11 - 0s - loss: 9.1235e-04 - 70ms/epoch - 6ms/step
# Epoch 394/1000
# 11/11 - 0s - loss: 9.0942e-04 - 78ms/epoch - 7ms/step
# Epoch 395/1000
# 11/11 - 0s - loss: 9.1788e-04 - 62ms/epoch - 6ms/step
# Epoch 396/1000
# 11/11 - 0s - loss: 9.1900e-04 - 69ms/epoch - 6ms/step
# Epoch 397/1000
# 11/11 - 0s - loss: 9.2746e-04 - 33ms/epoch - 3ms/step
# Epoch 398/1000
# 11/11 - 0s - loss: 9.1099e-04 - 34ms/epoch - 3ms/step
# Epoch 399/1000
# 11/11 - 0s - loss: 9.2539e-04 - 33ms/epoch - 3ms/step
# Epoch 400/1000
# 11/11 - 0s - loss: 9.1348e-04 - 33ms/epoch - 3ms/step
# Epoch 401/1000
# 11/11 - 0s - loss: 9.1452e-04 - 34ms/epoch - 3ms/step
# Epoch 402/1000
# 11/11 - 0s - loss: 9.6957e-04 - 31ms/epoch - 3ms/step
# Epoch 403/1000
# 11/11 - 0s - loss: 9.3708e-04 - 35ms/epoch - 3ms/step
# Epoch 404/1000
# 11/11 - 0s - loss: 9.2787e-04 - 33ms/epoch - 3ms/step
# Epoch 405/1000
# 11/11 - 0s - loss: 0.0010 - 39ms/epoch - 4ms/step
# Epoch 406/1000
# 11/11 - 0s - loss: 9.2823e-04 - 34ms/epoch - 3ms/step
# Epoch 407/1000
# 11/11 - 0s - loss: 9.0855e-04 - 32ms/epoch - 3ms/step
# Epoch 408/1000
# 11/11 - 0s - loss: 9.0217e-04 - 34ms/epoch - 3ms/step
# Epoch 409/1000
# 11/11 - 0s - loss: 9.5792e-04 - 64ms/epoch - 6ms/step
# Epoch 410/1000
# 11/11 - 0s - loss: 9.3606e-04 - 64ms/epoch - 6ms/step
# Epoch 411/1000
# 11/11 - 0s - loss: 9.6168e-04 - 64ms/epoch - 6ms/step
# Epoch 412/1000
# 11/11 - 0s - loss: 0.0013 - 61ms/epoch - 6ms/step
# Epoch 413/1000
# 11/11 - 0s - loss: 0.0014 - 58ms/epoch - 5ms/step
# Epoch 414/1000
# 11/11 - 0s - loss: 0.0011 - 75ms/epoch - 7ms/step
# Epoch 415/1000
# 11/11 - 0s - loss: 9.3135e-04 - 73ms/epoch - 7ms/step
# Epoch 416/1000
# 11/11 - 0s - loss: 9.2445e-04 - 71ms/epoch - 6ms/step
# Epoch 417/1000
# 11/11 - 0s - loss: 0.0011 - 33ms/epoch - 3ms/step
# Epoch 418/1000
# 11/11 - 0s - loss: 9.9874e-04 - 35ms/epoch - 3ms/step
# Epoch 419/1000
# 11/11 - 0s - loss: 9.2742e-04 - 35ms/epoch - 3ms/step
# Epoch 420/1000
# 11/11 - 0s - loss: 9.9522e-04 - 36ms/epoch - 3ms/step
# Epoch 421/1000
# 11/11 - 0s - loss: 9.7597e-04 - 36ms/epoch - 3ms/step
# Epoch 422/1000
# 11/11 - 0s - loss: 9.6426e-04 - 33ms/epoch - 3ms/step
# Epoch 423/1000
# 11/11 - 0s - loss: 9.3005e-04 - 34ms/epoch - 3ms/step
# Epoch 424/1000
# 11/11 - 0s - loss: 9.2443e-04 - 34ms/epoch - 3ms/step
# Epoch 425/1000
# 11/11 - 0s - loss: 9.0652e-04 - 40ms/epoch - 4ms/step
# Epoch 426/1000
# 11/11 - 0s - loss: 9.4799e-04 - 35ms/epoch - 3ms/step
# Epoch 427/1000
# 11/11 - 0s - loss: 9.5725e-04 - 33ms/epoch - 3ms/step
# Epoch 428/1000
# 11/11 - 0s - loss: 9.2300e-04 - 36ms/epoch - 3ms/step
# Epoch 429/1000
# 11/11 - 0s - loss: 9.6755e-04 - 38ms/epoch - 3ms/step
# Epoch 430/1000
# 11/11 - 0s - loss: 9.0374e-04 - 68ms/epoch - 6ms/step
# Epoch 431/1000
# 11/11 - 0s - loss: 9.1801e-04 - 55ms/epoch - 5ms/step
# Epoch 432/1000
# 11/11 - 0s - loss: 0.0010 - 67ms/epoch - 6ms/step
# Epoch 433/1000
# 11/11 - 0s - loss: 0.0011 - 66ms/epoch - 6ms/step
# Epoch 434/1000
# 11/11 - 0s - loss: 9.2222e-04 - 61ms/epoch - 6ms/step
# Epoch 435/1000
# 11/11 - 0s - loss: 9.3441e-04 - 64ms/epoch - 6ms/step
# Epoch 436/1000
# 11/11 - 0s - loss: 9.2930e-04 - 57ms/epoch - 5ms/step
# Epoch 437/1000
# 11/11 - 0s - loss: 9.0760e-04 - 48ms/epoch - 4ms/step
# Epoch 438/1000
# 11/11 - 0s - loss: 9.0677e-04 - 55ms/epoch - 5ms/step
# Epoch 439/1000
# 11/11 - 0s - loss: 9.1198e-04 - 45ms/epoch - 4ms/step
# Epoch 440/1000
# 11/11 - 0s - loss: 9.1369e-04 - 35ms/epoch - 3ms/step
# Epoch 441/1000
# 11/11 - 0s - loss: 9.0497e-04 - 35ms/epoch - 3ms/step
# Epoch 442/1000
# 11/11 - 0s - loss: 9.3903e-04 - 33ms/epoch - 3ms/step
# Epoch 443/1000
# 11/11 - 0s - loss: 9.3206e-04 - 38ms/epoch - 3ms/step
# Epoch 444/1000
# 11/11 - 0s - loss: 9.3162e-04 - 34ms/epoch - 3ms/step
# Epoch 445/1000
# 11/11 - 0s - loss: 9.4679e-04 - 36ms/epoch - 3ms/step
# Epoch 446/1000
# 11/11 - 0s - loss: 9.4834e-04 - 40ms/epoch - 4ms/step
# Epoch 447/1000
# 11/11 - 0s - loss: 9.7083e-04 - 35ms/epoch - 3ms/step
# Epoch 448/1000
# 11/11 - 0s - loss: 9.3295e-04 - 34ms/epoch - 3ms/step
# Epoch 449/1000
# 11/11 - 0s - loss: 9.0687e-04 - 34ms/epoch - 3ms/step
# Epoch 450/1000
# 11/11 - 0s - loss: 9.6267e-04 - 32ms/epoch - 3ms/step
# Epoch 451/1000
# 11/11 - 0s - loss: 9.4080e-04 - 34ms/epoch - 3ms/step
# Epoch 452/1000
# 11/11 - 0s - loss: 9.7823e-04 - 33ms/epoch - 3ms/step
# Epoch 453/1000
# 11/11 - 0s - loss: 9.5888e-04 - 34ms/epoch - 3ms/step
# Epoch 454/1000
# 11/11 - 0s - loss: 9.0669e-04 - 34ms/epoch - 3ms/step
# Epoch 455/1000
# 11/11 - 0s - loss: 9.0543e-04 - 36ms/epoch - 3ms/step
# Epoch 456/1000
# 11/11 - 0s - loss: 0.0010 - 33ms/epoch - 3ms/step
# Epoch 457/1000
# 11/11 - 0s - loss: 0.0012 - 35ms/epoch - 3ms/step
# Epoch 458/1000
# 11/11 - 0s - loss: 9.5597e-04 - 33ms/epoch - 3ms/step
# Epoch 459/1000
# 11/11 - 0s - loss: 9.8071e-04 - 34ms/epoch - 3ms/step
# Epoch 460/1000
# 11/11 - 0s - loss: 9.1620e-04 - 33ms/epoch - 3ms/step
# Epoch 461/1000
# 11/11 - 0s - loss: 9.1688e-04 - 35ms/epoch - 3ms/step
# Epoch 462/1000
# 11/11 - 0s - loss: 9.0910e-04 - 42ms/epoch - 4ms/step
# Epoch 463/1000
# 11/11 - 0s - loss: 9.0250e-04 - 36ms/epoch - 3ms/step
# Epoch 464/1000
# 11/11 - 0s - loss: 9.0104e-04 - 32ms/epoch - 3ms/step
# Epoch 465/1000
# 11/11 - 0s - loss: 9.3033e-04 - 34ms/epoch - 3ms/step
# Epoch 466/1000
# 11/11 - 0s - loss: 9.7221e-04 - 32ms/epoch - 3ms/step
# Epoch 467/1000
# 11/11 - 0s - loss: 9.1042e-04 - 34ms/epoch - 3ms/step
# Epoch 468/1000
# 11/11 - 0s - loss: 9.2387e-04 - 35ms/epoch - 3ms/step
# Epoch 469/1000
# 11/11 - 0s - loss: 9.1390e-04 - 36ms/epoch - 3ms/step
# Epoch 470/1000
# 11/11 - 0s - loss: 9.0992e-04 - 34ms/epoch - 3ms/step
# Epoch 471/1000
# 11/11 - 0s - loss: 9.7090e-04 - 32ms/epoch - 3ms/step
# Epoch 472/1000
# 11/11 - 0s - loss: 9.1873e-04 - 32ms/epoch - 3ms/step
# Epoch 473/1000
# 11/11 - 0s - loss: 9.3887e-04 - 41ms/epoch - 4ms/step
# Epoch 474/1000
# 11/11 - 0s - loss: 9.2106e-04 - 34ms/epoch - 3ms/step
# Epoch 475/1000
# 11/11 - 0s - loss: 9.2226e-04 - 32ms/epoch - 3ms/step
# Epoch 476/1000
# 11/11 - 0s - loss: 9.6857e-04 - 35ms/epoch - 3ms/step
# Epoch 477/1000
# 11/11 - 0s - loss: 9.2487e-04 - 34ms/epoch - 3ms/step
# Epoch 478/1000
# 11/11 - 0s - loss: 9.8680e-04 - 35ms/epoch - 3ms/step
# Epoch 479/1000
# 11/11 - 0s - loss: 0.0010 - 36ms/epoch - 3ms/step
# Epoch 480/1000
# 11/11 - 0s - loss: 9.4322e-04 - 35ms/epoch - 3ms/step
# Epoch 481/1000
# 11/11 - 0s - loss: 0.0012 - 35ms/epoch - 3ms/step
# Epoch 482/1000
# 11/11 - 0s - loss: 0.0011 - 35ms/epoch - 3ms/step
# Epoch 483/1000
# 11/11 - 0s - loss: 0.0011 - 38ms/epoch - 3ms/step
# Epoch 484/1000
# 11/11 - 0s - loss: 0.0010 - 33ms/epoch - 3ms/step
# Epoch 485/1000
# 11/11 - 0s - loss: 0.0010 - 33ms/epoch - 3ms/step
# Epoch 486/1000
# 11/11 - 0s - loss: 9.5366e-04 - 33ms/epoch - 3ms/step
# Epoch 487/1000
# 11/11 - 0s - loss: 0.0011 - 33ms/epoch - 3ms/step
# Epoch 488/1000
# 11/11 - 0s - loss: 0.0011 - 43ms/epoch - 4ms/step
# Epoch 489/1000
# 11/11 - 0s - loss: 9.0549e-04 - 34ms/epoch - 3ms/step
# Epoch 490/1000
# 11/11 - 0s - loss: 9.3175e-04 - 36ms/epoch - 3ms/step
# Epoch 491/1000
# 11/11 - 0s - loss: 9.0661e-04 - 34ms/epoch - 3ms/step
# Epoch 492/1000
# 11/11 - 0s - loss: 9.1922e-04 - 33ms/epoch - 3ms/step
# Epoch 493/1000
# 11/11 - 0s - loss: 9.2838e-04 - 35ms/epoch - 3ms/step
# Epoch 494/1000
# 11/11 - 0s - loss: 9.0761e-04 - 32ms/epoch - 3ms/step
# Epoch 495/1000
# 11/11 - 0s - loss: 9.6553e-04 - 37ms/epoch - 3ms/step
# Epoch 496/1000
# 11/11 - 0s - loss: 9.1553e-04 - 34ms/epoch - 3ms/step
# Epoch 497/1000
# 11/11 - 0s - loss: 9.1654e-04 - 34ms/epoch - 3ms/step
# Epoch 498/1000
# 11/11 - 0s - loss: 9.0899e-04 - 36ms/epoch - 3ms/step
# Epoch 499/1000
# 11/11 - 0s - loss: 0.0010 - 35ms/epoch - 3ms/step
# Epoch 500/1000
# 11/11 - 0s - loss: 9.2173e-04 - 36ms/epoch - 3ms/step
# Epoch 501/1000
# 11/11 - 0s - loss: 9.5285e-04 - 33ms/epoch - 3ms/step
# Epoch 502/1000
# 11/11 - 0s - loss: 9.0518e-04 - 32ms/epoch - 3ms/step
# Epoch 503/1000
# 11/11 - 0s - loss: 9.2390e-04 - 31ms/epoch - 3ms/step
# Epoch 504/1000
# 11/11 - 0s - loss: 9.5436e-04 - 35ms/epoch - 3ms/step
# Epoch 505/1000
# 11/11 - 0s - loss: 9.2498e-04 - 38ms/epoch - 3ms/step
# Epoch 506/1000
# 11/11 - 0s - loss: 9.5017e-04 - 36ms/epoch - 3ms/step
# Epoch 507/1000
# 11/11 - 0s - loss: 0.0010 - 35ms/epoch - 3ms/step
# Epoch 508/1000
# 11/11 - 0s - loss: 8.9854e-04 - 36ms/epoch - 3ms/step
# Epoch 509/1000
# 11/11 - 0s - loss: 9.1387e-04 - 34ms/epoch - 3ms/step
# Epoch 510/1000
# 11/11 - 0s - loss: 0.0013 - 33ms/epoch - 3ms/step
# Epoch 511/1000
# 11/11 - 0s - loss: 0.0012 - 34ms/epoch - 3ms/step
# Epoch 512/1000
# 11/11 - 0s - loss: 0.0010 - 34ms/epoch - 3ms/step
# Epoch 513/1000
# 11/11 - 0s - loss: 9.8934e-04 - 35ms/epoch - 3ms/step
# Epoch 514/1000
# 11/11 - 0s - loss: 9.0013e-04 - 47ms/epoch - 4ms/step
# Epoch 515/1000
# 11/11 - 0s - loss: 8.9881e-04 - 35ms/epoch - 3ms/step
# Epoch 516/1000
# 11/11 - 0s - loss: 9.0163e-04 - 33ms/epoch - 3ms/step
# Epoch 517/1000
# 11/11 - 0s - loss: 9.7700e-04 - 34ms/epoch - 3ms/step
# Epoch 518/1000
# 11/11 - 0s - loss: 9.2322e-04 - 35ms/epoch - 3ms/step
# Epoch 519/1000
# 11/11 - 0s - loss: 9.2490e-04 - 40ms/epoch - 4ms/step
# Epoch 520/1000
# 11/11 - 0s - loss: 9.1350e-04 - 33ms/epoch - 3ms/step
# Epoch 521/1000
# 11/11 - 0s - loss: 9.1936e-04 - 36ms/epoch - 3ms/step
# Epoch 522/1000
# 11/11 - 0s - loss: 0.0010 - 61ms/epoch - 6ms/step
# Epoch 523/1000
# 11/11 - 0s - loss: 9.0231e-04 - 33ms/epoch - 3ms/step
# Epoch 524/1000
# 11/11 - 0s - loss: 9.5006e-04 - 38ms/epoch - 3ms/step
# Epoch 525/1000
# 11/11 - 0s - loss: 9.8889e-04 - 34ms/epoch - 3ms/step
# Epoch 526/1000
# 11/11 - 0s - loss: 0.0011 - 34ms/epoch - 3ms/step
# Epoch 527/1000
# 11/11 - 0s - loss: 9.9445e-04 - 35ms/epoch - 3ms/step
# Epoch 528/1000
# 11/11 - 0s - loss: 0.0010 - 34ms/epoch - 3ms/step
# Epoch 529/1000
# 11/11 - 0s - loss: 9.6064e-04 - 35ms/epoch - 3ms/step
# Epoch 530/1000
# 11/11 - 0s - loss: 9.6197e-04 - 38ms/epoch - 3ms/step
# Epoch 531/1000
# 11/11 - 0s - loss: 9.5546e-04 - 38ms/epoch - 3ms/step
# Epoch 532/1000
# 11/11 - 0s - loss: 0.0011 - 37ms/epoch - 3ms/step
# Epoch 533/1000
# 11/11 - 0s - loss: 9.5655e-04 - 35ms/epoch - 3ms/step
# Epoch 534/1000
# 11/11 - 0s - loss: 9.5174e-04 - 35ms/epoch - 3ms/step
# Epoch 535/1000
# 11/11 - 0s - loss: 9.7658e-04 - 35ms/epoch - 3ms/step
# Epoch 536/1000
# 11/11 - 0s - loss: 0.0011 - 36ms/epoch - 3ms/step
# Epoch 537/1000
# 11/11 - 0s - loss: 0.0010 - 36ms/epoch - 3ms/step
# Epoch 538/1000
# 11/11 - 0s - loss: 9.8382e-04 - 49ms/epoch - 4ms/step
# Epoch 539/1000
# 11/11 - 0s - loss: 9.2475e-04 - 37ms/epoch - 3ms/step
# Epoch 540/1000
# 11/11 - 0s - loss: 0.0010 - 39ms/epoch - 4ms/step
# Epoch 541/1000
# 11/11 - 0s - loss: 9.2073e-04 - 35ms/epoch - 3ms/step
# Epoch 542/1000
# 11/11 - 0s - loss: 0.0010 - 34ms/epoch - 3ms/step
# Epoch 543/1000
# 11/11 - 0s - loss: 9.1614e-04 - 33ms/epoch - 3ms/step
# Epoch 544/1000
# 11/11 - 0s - loss: 9.0276e-04 - 36ms/epoch - 3ms/step
# Epoch 545/1000
# 11/11 - 0s - loss: 9.0252e-04 - 37ms/epoch - 3ms/step
# Epoch 546/1000
# 11/11 - 0s - loss: 9.0394e-04 - 33ms/epoch - 3ms/step
# Epoch 547/1000
# 11/11 - 0s - loss: 9.1016e-04 - 34ms/epoch - 3ms/step
# Epoch 548/1000
# 11/11 - 0s - loss: 9.1047e-04 - 38ms/epoch - 3ms/step
# Epoch 549/1000
# 11/11 - 0s - loss: 9.2788e-04 - 35ms/epoch - 3ms/step
# Epoch 550/1000
# 11/11 - 0s - loss: 9.2434e-04 - 34ms/epoch - 3ms/step
# Epoch 551/1000
# 11/11 - 0s - loss: 9.1454e-04 - 33ms/epoch - 3ms/step
# Epoch 552/1000
# 11/11 - 0s - loss: 8.9784e-04 - 35ms/epoch - 3ms/step
# Epoch 553/1000
# 11/11 - 0s - loss: 8.9232e-04 - 35ms/epoch - 3ms/step
# Epoch 554/1000
# 11/11 - 0s - loss: 8.9673e-04 - 36ms/epoch - 3ms/step
# Epoch 555/1000
# 11/11 - 0s - loss: 8.9454e-04 - 33ms/epoch - 3ms/step
# Epoch 556/1000
# 11/11 - 0s - loss: 9.6080e-04 - 37ms/epoch - 3ms/step
# Epoch 557/1000
# 11/11 - 0s - loss: 9.5499e-04 - 33ms/epoch - 3ms/step
# Epoch 558/1000
# 11/11 - 0s - loss: 0.0011 - 33ms/epoch - 3ms/step
# Epoch 559/1000
# 11/11 - 0s - loss: 0.0011 - 34ms/epoch - 3ms/step
# Epoch 560/1000
# 11/11 - 0s - loss: 0.0011 - 34ms/epoch - 3ms/step
# Epoch 561/1000
# 11/11 - 0s - loss: 0.0012 - 33ms/epoch - 3ms/step
# Epoch 562/1000
# 11/11 - 0s - loss: 0.0011 - 34ms/epoch - 3ms/step
# Epoch 563/1000
# 11/11 - 0s - loss: 9.6659e-04 - 35ms/epoch - 3ms/step
# Epoch 564/1000
# 11/11 - 0s - loss: 9.0163e-04 - 38ms/epoch - 3ms/step
# Epoch 565/1000
# 11/11 - 0s - loss: 9.2835e-04 - 32ms/epoch - 3ms/step
# Epoch 566/1000
# 11/11 - 0s - loss: 9.0451e-04 - 36ms/epoch - 3ms/step
# Epoch 567/1000
# 11/11 - 0s - loss: 9.2936e-04 - 33ms/epoch - 3ms/step
# Epoch 568/1000
# 11/11 - 0s - loss: 0.0010 - 33ms/epoch - 3ms/step
# Epoch 569/1000
# 11/11 - 0s - loss: 9.2991e-04 - 32ms/epoch - 3ms/step
# Epoch 570/1000
# 11/11 - 0s - loss: 8.8989e-04 - 34ms/epoch - 3ms/step
# Epoch 571/1000
# 11/11 - 0s - loss: 9.3351e-04 - 32ms/epoch - 3ms/step
# Epoch 572/1000
# 11/11 - 0s - loss: 0.0011 - 37ms/epoch - 3ms/step
# Epoch 573/1000
# 11/11 - 0s - loss: 9.4903e-04 - 34ms/epoch - 3ms/step
# Epoch 574/1000
# 11/11 - 0s - loss: 9.1347e-04 - 35ms/epoch - 3ms/step
# Epoch 575/1000
# 11/11 - 0s - loss: 9.4098e-04 - 35ms/epoch - 3ms/step
# Epoch 576/1000
# 11/11 - 0s - loss: 9.0023e-04 - 37ms/epoch - 3ms/step
# Epoch 577/1000
# 11/11 - 0s - loss: 8.9337e-04 - 34ms/epoch - 3ms/step
# Epoch 578/1000
# 11/11 - 0s - loss: 9.5799e-04 - 35ms/epoch - 3ms/step
# Epoch 579/1000
# 11/11 - 0s - loss: 9.4537e-04 - 33ms/epoch - 3ms/step
# Epoch 580/1000
# 11/11 - 0s - loss: 8.9314e-04 - 37ms/epoch - 3ms/step
# Epoch 581/1000
# 11/11 - 0s - loss: 9.1159e-04 - 35ms/epoch - 3ms/step
# Epoch 582/1000
# 11/11 - 0s - loss: 9.0817e-04 - 34ms/epoch - 3ms/step
# Epoch 583/1000
# 11/11 - 0s - loss: 8.9514e-04 - 32ms/epoch - 3ms/step
# Epoch 584/1000
# 11/11 - 0s - loss: 8.9805e-04 - 34ms/epoch - 3ms/step
# Epoch 585/1000
# 11/11 - 0s - loss: 9.0256e-04 - 37ms/epoch - 3ms/step
# Epoch 586/1000
# 11/11 - 0s - loss: 9.0774e-04 - 33ms/epoch - 3ms/step
# Epoch 587/1000
# 11/11 - 0s - loss: 9.1880e-04 - 33ms/epoch - 3ms/step
# Epoch 588/1000
# 11/11 - 0s - loss: 0.0010 - 33ms/epoch - 3ms/step
# Epoch 589/1000
# 11/11 - 0s - loss: 9.0243e-04 - 33ms/epoch - 3ms/step
# Epoch 590/1000
# 11/11 - 0s - loss: 9.0399e-04 - 34ms/epoch - 3ms/step
# Epoch 591/1000
# 11/11 - 0s - loss: 9.0561e-04 - 51ms/epoch - 5ms/step
# Epoch 592/1000
# 11/11 - 0s - loss: 9.0546e-04 - 34ms/epoch - 3ms/step
# Epoch 593/1000
# 11/11 - 0s - loss: 9.1375e-04 - 32ms/epoch - 3ms/step
# Epoch 594/1000
# 11/11 - 0s - loss: 9.0868e-04 - 33ms/epoch - 3ms/step
# Epoch 595/1000
# 11/11 - 0s - loss: 9.2676e-04 - 35ms/epoch - 3ms/step
# Epoch 596/1000
# 11/11 - 0s - loss: 9.0927e-04 - 40ms/epoch - 4ms/step
# Epoch 597/1000
# 11/11 - 0s - loss: 9.0064e-04 - 36ms/epoch - 3ms/step
# Epoch 598/1000
# 11/11 - 0s - loss: 8.8903e-04 - 37ms/epoch - 3ms/step
# Epoch 599/1000
# 11/11 - 0s - loss: 8.9904e-04 - 33ms/epoch - 3ms/step
# Epoch 600/1000
# 11/11 - 0s - loss: 9.0714e-04 - 32ms/epoch - 3ms/step
# Epoch 601/1000
# 11/11 - 0s - loss: 9.3290e-04 - 40ms/epoch - 4ms/step
# Epoch 602/1000
# 11/11 - 0s - loss: 8.9908e-04 - 31ms/epoch - 3ms/step
# Epoch 603/1000
# 11/11 - 0s - loss: 9.0787e-04 - 32ms/epoch - 3ms/step
# Epoch 604/1000
# 11/11 - 0s - loss: 9.1946e-04 - 33ms/epoch - 3ms/step
# Epoch 605/1000
# 11/11 - 0s - loss: 9.6804e-04 - 34ms/epoch - 3ms/step
# Epoch 606/1000
# 11/11 - 0s - loss: 9.1315e-04 - 35ms/epoch - 3ms/step
# Epoch 607/1000
# 11/11 - 0s - loss: 9.0499e-04 - 39ms/epoch - 4ms/step
# Epoch 608/1000
# 11/11 - 0s - loss: 8.9963e-04 - 33ms/epoch - 3ms/step
# Epoch 609/1000
# 11/11 - 0s - loss: 9.7602e-04 - 34ms/epoch - 3ms/step
# Epoch 610/1000
# 11/11 - 0s - loss: 9.0974e-04 - 37ms/epoch - 3ms/step
# Epoch 611/1000
# 11/11 - 0s - loss: 9.2921e-04 - 35ms/epoch - 3ms/step
# Epoch 612/1000
# 11/11 - 0s - loss: 9.2413e-04 - 38ms/epoch - 3ms/step
# Epoch 613/1000
# 11/11 - 0s - loss: 9.2171e-04 - 39ms/epoch - 4ms/step
# Epoch 614/1000
# 11/11 - 0s - loss: 0.0010 - 37ms/epoch - 3ms/step
# Epoch 615/1000
# 11/11 - 0s - loss: 9.1147e-04 - 38ms/epoch - 3ms/step
# Epoch 616/1000
# 11/11 - 0s - loss: 9.0767e-04 - 45ms/epoch - 4ms/step
# Epoch 617/1000
# 11/11 - 0s - loss: 0.0010 - 38ms/epoch - 3ms/step
# Epoch 618/1000
# 11/11 - 0s - loss: 9.3799e-04 - 34ms/epoch - 3ms/step
# Epoch 619/1000
# 11/11 - 0s - loss: 9.0710e-04 - 35ms/epoch - 3ms/step
# Epoch 620/1000
# 11/11 - 0s - loss: 8.9393e-04 - 39ms/epoch - 4ms/step
# Epoch 621/1000
# 11/11 - 0s - loss: 9.5145e-04 - 35ms/epoch - 3ms/step
# Epoch 622/1000
# 11/11 - 0s - loss: 9.2954e-04 - 35ms/epoch - 3ms/step
# Epoch 623/1000
# 11/11 - 0s - loss: 9.0342e-04 - 35ms/epoch - 3ms/step
# Epoch 624/1000
# 11/11 - 0s - loss: 9.4151e-04 - 33ms/epoch - 3ms/step
# Epoch 625/1000
# 11/11 - 0s - loss: 8.9976e-04 - 33ms/epoch - 3ms/step
# Epoch 626/1000
# 11/11 - 0s - loss: 9.0606e-04 - 34ms/epoch - 3ms/step
# Epoch 627/1000
# 11/11 - 0s - loss: 0.0011 - 37ms/epoch - 3ms/step
# Epoch 628/1000
# 11/11 - 0s - loss: 9.1310e-04 - 32ms/epoch - 3ms/step
# Epoch 629/1000
# 11/11 - 0s - loss: 9.1132e-04 - 35ms/epoch - 3ms/step
# Epoch 630/1000
# 11/11 - 0s - loss: 9.0459e-04 - 36ms/epoch - 3ms/step
# Epoch 631/1000
# 11/11 - 0s - loss: 9.3715e-04 - 37ms/epoch - 3ms/step
# Epoch 632/1000
# 11/11 - 0s - loss: 9.0304e-04 - 35ms/epoch - 3ms/step
# Epoch 633/1000
# 11/11 - 0s - loss: 8.8762e-04 - 33ms/epoch - 3ms/step
# Epoch 634/1000
# 11/11 - 0s - loss: 9.7033e-04 - 33ms/epoch - 3ms/step
# Epoch 635/1000
# 11/11 - 0s - loss: 0.0011 - 32ms/epoch - 3ms/step
# Epoch 636/1000
# 11/11 - 0s - loss: 9.0265e-04 - 33ms/epoch - 3ms/step
# Epoch 637/1000
# 11/11 - 0s - loss: 9.1927e-04 - 32ms/epoch - 3ms/step
# Epoch 638/1000
# 11/11 - 0s - loss: 9.1794e-04 - 33ms/epoch - 3ms/step
# Epoch 639/1000
# 11/11 - 0s - loss: 9.3447e-04 - 34ms/epoch - 3ms/step
# Epoch 640/1000
# 11/11 - 0s - loss: 8.9956e-04 - 37ms/epoch - 3ms/step
# Epoch 641/1000
# 11/11 - 0s - loss: 8.8942e-04 - 40ms/epoch - 4ms/step
# Epoch 642/1000
# 11/11 - 0s - loss: 8.9790e-04 - 46ms/epoch - 4ms/step
# Epoch 643/1000
# 11/11 - 0s - loss: 9.5105e-04 - 34ms/epoch - 3ms/step
# Epoch 644/1000
# 11/11 - 0s - loss: 9.1488e-04 - 38ms/epoch - 3ms/step
# Epoch 645/1000
# 11/11 - 0s - loss: 9.3785e-04 - 38ms/epoch - 3ms/step
# Epoch 646/1000
# 11/11 - 0s - loss: 8.8908e-04 - 37ms/epoch - 3ms/step
# Epoch 647/1000
# 11/11 - 0s - loss: 8.8880e-04 - 33ms/epoch - 3ms/step
# Epoch 648/1000
# 11/11 - 0s - loss: 8.8271e-04 - 37ms/epoch - 3ms/step
# Epoch 649/1000
# 11/11 - 0s - loss: 0.0011 - 37ms/epoch - 3ms/step
# Epoch 650/1000
# 11/11 - 0s - loss: 0.0011 - 36ms/epoch - 3ms/step
# Epoch 651/1000
# 11/11 - 0s - loss: 9.1855e-04 - 37ms/epoch - 3ms/step
# Epoch 652/1000
# 11/11 - 0s - loss: 9.1032e-04 - 37ms/epoch - 3ms/step
# Epoch 653/1000
# 11/11 - 0s - loss: 9.0440e-04 - 34ms/epoch - 3ms/step
# Epoch 654/1000
# 11/11 - 0s - loss: 9.7003e-04 - 34ms/epoch - 3ms/step
# Epoch 655/1000
# 11/11 - 0s - loss: 9.2357e-04 - 32ms/epoch - 3ms/step
# Epoch 656/1000
# 11/11 - 0s - loss: 9.1304e-04 - 32ms/epoch - 3ms/step
# Epoch 657/1000
# 11/11 - 0s - loss: 9.0453e-04 - 35ms/epoch - 3ms/step
# Epoch 658/1000
# 11/11 - 0s - loss: 0.0010 - 34ms/epoch - 3ms/step
# Epoch 659/1000
# 11/11 - 0s - loss: 0.0010 - 32ms/epoch - 3ms/step
# Epoch 660/1000
# 11/11 - 0s - loss: 9.0061e-04 - 34ms/epoch - 3ms/step
# Epoch 661/1000
# 11/11 - 0s - loss: 9.6517e-04 - 37ms/epoch - 3ms/step
# Epoch 662/1000
# 11/11 - 0s - loss: 9.2571e-04 - 32ms/epoch - 3ms/step
# Epoch 663/1000
# 11/11 - 0s - loss: 8.8994e-04 - 35ms/epoch - 3ms/step
# Epoch 664/1000
# 11/11 - 0s - loss: 9.1955e-04 - 35ms/epoch - 3ms/step
# Epoch 665/1000
# 11/11 - 0s - loss: 8.9609e-04 - 37ms/epoch - 3ms/step
# Epoch 666/1000
# 11/11 - 0s - loss: 8.9000e-04 - 32ms/epoch - 3ms/step
# Epoch 667/1000
# 11/11 - 0s - loss: 9.1068e-04 - 39ms/epoch - 4ms/step
# Epoch 668/1000
# 11/11 - 0s - loss: 9.1713e-04 - 38ms/epoch - 3ms/step
# Epoch 669/1000
# 11/11 - 0s - loss: 8.9207e-04 - 37ms/epoch - 3ms/step
# Epoch 670/1000
# 11/11 - 0s - loss: 9.1402e-04 - 36ms/epoch - 3ms/step
# Epoch 671/1000
# 11/11 - 0s - loss: 9.0585e-04 - 35ms/epoch - 3ms/step
# Epoch 672/1000
# 11/11 - 0s - loss: 8.9390e-04 - 31ms/epoch - 3ms/step
# Epoch 673/1000
# 11/11 - 0s - loss: 9.0520e-04 - 34ms/epoch - 3ms/step
# Epoch 674/1000
# 11/11 - 0s - loss: 8.9049e-04 - 33ms/epoch - 3ms/step
# Epoch 675/1000
# 11/11 - 0s - loss: 9.0806e-04 - 33ms/epoch - 3ms/step
# Epoch 676/1000
# 11/11 - 0s - loss: 9.1518e-04 - 37ms/epoch - 3ms/step
# Epoch 677/1000
# 11/11 - 0s - loss: 9.3814e-04 - 34ms/epoch - 3ms/step
# Epoch 678/1000
# 11/11 - 0s - loss: 9.1910e-04 - 32ms/epoch - 3ms/step
# Epoch 679/1000
# 11/11 - 0s - loss: 9.4632e-04 - 35ms/epoch - 3ms/step
# Epoch 680/1000
# 11/11 - 0s - loss: 0.0010 - 32ms/epoch - 3ms/step
# Epoch 681/1000
# 11/11 - 0s - loss: 0.0010 - 36ms/epoch - 3ms/step
# Epoch 682/1000
# 11/11 - 0s - loss: 9.1959e-04 - 37ms/epoch - 3ms/step
# Epoch 683/1000
# 11/11 - 0s - loss: 9.6875e-04 - 34ms/epoch - 3ms/step
# Epoch 684/1000
# 11/11 - 0s - loss: 9.1993e-04 - 33ms/epoch - 3ms/step
# Epoch 685/1000
# 11/11 - 0s - loss: 8.9384e-04 - 35ms/epoch - 3ms/step
# Epoch 686/1000
# 11/11 - 0s - loss: 9.4597e-04 - 37ms/epoch - 3ms/step
# Epoch 687/1000
# 11/11 - 0s - loss: 9.2905e-04 - 34ms/epoch - 3ms/step
# Epoch 688/1000
# 11/11 - 0s - loss: 0.0010 - 34ms/epoch - 3ms/step
# Epoch 689/1000
# 11/11 - 0s - loss: 8.8499e-04 - 34ms/epoch - 3ms/step
# Epoch 690/1000
# 11/11 - 0s - loss: 9.0626e-04 - 35ms/epoch - 3ms/step
# Epoch 691/1000
# 11/11 - 0s - loss: 8.8541e-04 - 36ms/epoch - 3ms/step
# Epoch 692/1000
# 11/11 - 0s - loss: 9.6651e-04 - 33ms/epoch - 3ms/step
# Epoch 693/1000
# 11/11 - 0s - loss: 9.6824e-04 - 42ms/epoch - 4ms/step
# Epoch 694/1000
# 11/11 - 0s - loss: 0.0013 - 43ms/epoch - 4ms/step
# Epoch 695/1000
# 11/11 - 0s - loss: 9.8302e-04 - 35ms/epoch - 3ms/step
# Epoch 696/1000
# 11/11 - 0s - loss: 9.3210e-04 - 39ms/epoch - 4ms/step
# Epoch 697/1000
# 11/11 - 0s - loss: 9.7036e-04 - 44ms/epoch - 4ms/step
# Epoch 698/1000
# 11/11 - 0s - loss: 9.4033e-04 - 47ms/epoch - 4ms/step
# Epoch 699/1000
# 11/11 - 0s - loss: 8.9129e-04 - 35ms/epoch - 3ms/step
# Epoch 700/1000
# 11/11 - 0s - loss: 9.0751e-04 - 34ms/epoch - 3ms/step
# Epoch 701/1000
# 11/11 - 0s - loss: 8.8557e-04 - 33ms/epoch - 3ms/step
# Epoch 702/1000
# 11/11 - 0s - loss: 8.8569e-04 - 34ms/epoch - 3ms/step
# Epoch 703/1000
# 11/11 - 0s - loss: 9.0169e-04 - 34ms/epoch - 3ms/step
# Epoch 704/1000
# 11/11 - 0s - loss: 8.9272e-04 - 33ms/epoch - 3ms/step
# Epoch 705/1000
# ...
# Epoch 778/1000
# 11/11 - 0s - loss: 9.2854e-04 - 37ms/epoch - 3ms/step
# Epoch 779/1000
# 11/11 - 0s - loss: 9.0322e-04 - 33ms/epoch - 3ms/step
# Epoch 780/1000
# 11/11 - 0s - loss: 9.1154e-04 - 34ms/epoch - 3ms/step
# Epoch 781/1000
# 11/11 - 0s - loss: 9.2723e-04 - 51ms/epoch - 5ms/step
# Epoch 782/1000
# 11/11 - 0s - loss: 8.8591e-04 - 42ms/epoch - 4ms/step
# Epoch 783/1000
# 11/11 - 0s - loss: 9.2180e-04 - 35ms/epoch - 3ms/step
# Epoch 784/1000
# 11/11 - 0s - loss: 8.9109e-04 - 33ms/epoch - 3ms/step
# Epoch 785/1000
# 11/11 - 0s - loss: 8.8019e-04 - 32ms/epoch - 3ms/step
# Epoch 786/1000
# 11/11 - 0s - loss: 9.0448e-04 - 36ms/epoch - 3ms/step
# Epoch 787/1000
# 11/11 - 0s - loss: 9.6348e-04 - 36ms/epoch - 3ms/step
# Epoch 788/1000
# 11/11 - 0s - loss: 9.1864e-04 - 40ms/epoch - 4ms/step
# Epoch 789/1000
# 11/11 - 0s - loss: 8.7495e-04 - 34ms/epoch - 3ms/step
# Epoch 790/1000
# 11/11 - 0s - loss: 8.9106e-04 - 33ms/epoch - 3ms/step
# Epoch 791/1000
# 11/11 - 0s - loss: 8.7871e-04 - 33ms/epoch - 3ms/step
# Epoch 792/1000
# 11/11 - 0s - loss: 8.8704e-04 - 32ms/epoch - 3ms/step
# Epoch 793/1000
# 11/11 - 0s - loss: 9.9131e-04 - 34ms/epoch - 3ms/step
# Epoch 794/1000
# 11/11 - 0s - loss: 9.8995e-04 - 37ms/epoch - 3ms/step
# Epoch 795/1000
# 11/11 - 0s - loss: 8.9237e-04 - 42ms/epoch - 4ms/step
# Epoch 796/1000
# 11/11 - 0s - loss: 9.0500e-04 - 44ms/epoch - 4ms/step
# Epoch 797/1000
# 11/11 - 0s - loss: 8.8368e-04 - 31ms/epoch - 3ms/step
# Epoch 798/1000
# 11/11 - 0s - loss: 8.9637e-04 - 34ms/epoch - 3ms/step
# Epoch 799/1000
# 11/11 - 0s - loss: 9.0213e-04 - 34ms/epoch - 3ms/step
# Epoch 800/1000
# 11/11 - 0s - loss: 8.9336e-04 - 35ms/epoch - 3ms/step
# Epoch 801/1000
# 11/11 - 0s - loss: 8.8958e-04 - 34ms/epoch - 3ms/step
# Epoch 802/1000
# 11/11 - 0s - loss: 8.8391e-04 - 31ms/epoch - 3ms/step
# Epoch 803/1000
# 11/11 - 0s - loss: 0.0011 - 37ms/epoch - 3ms/step
# Epoch 804/1000
# 11/11 - 0s - loss: 9.7474e-04 - 33ms/epoch - 3ms/step
# Epoch 805/1000
# 11/11 - 0s - loss: 9.2835e-04 - 34ms/epoch - 3ms/step
# Epoch 806/1000
# 11/11 - 0s - loss: 9.8599e-04 - 33ms/epoch - 3ms/step
# Epoch 807/1000
# 11/11 - 0s - loss: 9.6627e-04 - 35ms/epoch - 3ms/step
# Epoch 808/1000
# 11/11 - 0s - loss: 9.1064e-04 - 39ms/epoch - 4ms/step
# Epoch 809/1000
# 11/11 - 0s - loss: 8.9125e-04 - 37ms/epoch - 3ms/step
# Epoch 810/1000
# 11/11 - 0s - loss: 8.7919e-04 - 35ms/epoch - 3ms/step
# Epoch 811/1000
# 11/11 - 0s - loss: 8.8271e-04 - 36ms/epoch - 3ms/step
# Epoch 812/1000
# 11/11 - 0s - loss: 8.8420e-04 - 34ms/epoch - 3ms/step
# Epoch 813/1000
# 11/11 - 0s - loss: 8.6944e-04 - 34ms/epoch - 3ms/step
# Epoch 814/1000
# 11/11 - 0s - loss: 8.9119e-04 - 32ms/epoch - 3ms/step
# Epoch 815/1000
# 11/11 - 0s - loss: 8.9366e-04 - 37ms/epoch - 3ms/step
# Epoch 816/1000
# 11/11 - 0s - loss: 9.4076e-04 - 36ms/epoch - 3ms/step
# Epoch 817/1000
# 11/11 - 0s - loss: 8.9913e-04 - 34ms/epoch - 3ms/step
# Epoch 818/1000
# 11/11 - 0s - loss: 8.8690e-04 - 36ms/epoch - 3ms/step
# Epoch 819/1000
# 11/11 - 0s - loss: 8.8248e-04 - 35ms/epoch - 3ms/step
# Epoch 820/1000
# 11/11 - 0s - loss: 8.8699e-04 - 36ms/epoch - 3ms/step
# Epoch 821/1000
# 11/11 - 0s - loss: 8.8671e-04 - 42ms/epoch - 4ms/step
# Epoch 822/1000
# 11/11 - 0s - loss: 8.7782e-04 - 37ms/epoch - 3ms/step
# Epoch 823/1000
# 11/11 - 0s - loss: 9.1398e-04 - 35ms/epoch - 3ms/step
# Epoch 824/1000
# 11/11 - 0s - loss: 9.0275e-04 - 37ms/epoch - 3ms/step
# Epoch 825/1000
# 11/11 - 0s - loss: 9.3329e-04 - 38ms/epoch - 3ms/step
# Epoch 826/1000
# 11/11 - 0s - loss: 9.1470e-04 - 36ms/epoch - 3ms/step
# Epoch 827/1000
# 11/11 - 0s - loss: 8.8570e-04 - 38ms/epoch - 3ms/step
# Epoch 828/1000
# 11/11 - 0s - loss: 9.1712e-04 - 41ms/epoch - 4ms/step
# Epoch 829/1000
# 11/11 - 0s - loss: 9.8665e-04 - 36ms/epoch - 3ms/step
# Epoch 830/1000
# 11/11 - 0s - loss: 8.9354e-04 - 36ms/epoch - 3ms/step
# Epoch 831/1000
# 11/11 - 0s - loss: 8.9769e-04 - 35ms/epoch - 3ms/step
# Epoch 832/1000
# 11/11 - 0s - loss: 9.2248e-04 - 38ms/epoch - 3ms/step
# Epoch 833/1000
# 11/11 - 0s - loss: 8.8716e-04 - 34ms/epoch - 3ms/step
# Epoch 834/1000
# 11/11 - 0s - loss: 9.1079e-04 - 35ms/epoch - 3ms/step
# Epoch 835/1000
# 11/11 - 0s - loss: 0.0010 - 36ms/epoch - 3ms/step
# Epoch 836/1000
# 11/11 - 0s - loss: 0.0011 - 36ms/epoch - 3ms/step
# Epoch 837/1000
# 11/11 - 0s - loss: 9.6320e-04 - 34ms/epoch - 3ms/step
# Epoch 838/1000
# 11/11 - 0s - loss: 9.0739e-04 - 36ms/epoch - 3ms/step
# Epoch 839/1000
# 11/11 - 0s - loss: 9.2741e-04 - 35ms/epoch - 3ms/step
# Epoch 840/1000
# 11/11 - 0s - loss: 8.8801e-04 - 36ms/epoch - 3ms/step
# Epoch 841/1000
# 11/11 - 0s - loss: 8.7564e-04 - 32ms/epoch - 3ms/step
# Epoch 842/1000
# 11/11 - 0s - loss: 8.9458e-04 - 32ms/epoch - 3ms/step
# Epoch 843/1000
# 11/11 - 0s - loss: 8.9746e-04 - 34ms/epoch - 3ms/step
# Epoch 844/1000
# 11/11 - 0s - loss: 0.0011 - 35ms/epoch - 3ms/step
# Epoch 845/1000
# 11/11 - 0s - loss: 0.0015 - 35ms/epoch - 3ms/step
# Epoch 846/1000
# 11/11 - 0s - loss: 0.0010 - 40ms/epoch - 4ms/step
# Epoch 847/1000
# 11/11 - 0s - loss: 8.8886e-04 - 43ms/epoch - 4ms/step
# Epoch 848/1000
# 11/11 - 0s - loss: 9.2857e-04 - 35ms/epoch - 3ms/step
# Epoch 849/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 850/1000
# 11/11 - 0s - loss: 9.9687e-04 - 34ms/epoch - 3ms/step
# Epoch 851/1000
# 11/11 - 0s - loss: 0.0010 - 38ms/epoch - 3ms/step
# Epoch 852/1000
# 11/11 - 0s - loss: 9.4112e-04 - 34ms/epoch - 3ms/step
# Epoch 853/1000
# 11/11 - 0s - loss: 9.6842e-04 - 35ms/epoch - 3ms/step
# Epoch 854/1000
# 11/11 - 0s - loss: 9.2101e-04 - 35ms/epoch - 3ms/step
# Epoch 855/1000
# 11/11 - 0s - loss: 9.4245e-04 - 36ms/epoch - 3ms/step
# Epoch 856/1000
# 11/11 - 0s - loss: 8.8716e-04 - 32ms/epoch - 3ms/step
# Epoch 857/1000
# 11/11 - 0s - loss: 9.0590e-04 - 36ms/epoch - 3ms/step
# Epoch 858/1000
# 11/11 - 0s - loss: 9.1469e-04 - 35ms/epoch - 3ms/step
# Epoch 859/1000
# 11/11 - 0s - loss: 9.3210e-04 - 32ms/epoch - 3ms/step
# Epoch 860/1000
# 11/11 - 0s - loss: 9.6850e-04 - 35ms/epoch - 3ms/step
# Epoch 861/1000
# 11/11 - 0s - loss: 9.1181e-04 - 37ms/epoch - 3ms/step
# Epoch 862/1000
# 11/11 - 0s - loss: 9.6094e-04 - 35ms/epoch - 3ms/step
# Epoch 863/1000
# 11/11 - 0s - loss: 9.2327e-04 - 34ms/epoch - 3ms/step
# Epoch 864/1000
# 11/11 - 0s - loss: 8.8946e-04 - 37ms/epoch - 3ms/step
# Epoch 865/1000
# 11/11 - 0s - loss: 8.8912e-04 - 34ms/epoch - 3ms/step
# Epoch 866/1000
# 11/11 - 0s - loss: 0.0011 - 35ms/epoch - 3ms/step
# Epoch 867/1000
# 11/11 - 0s - loss: 0.0010 - 38ms/epoch - 3ms/step
# Epoch 868/1000
# 11/11 - 0s - loss: 9.7075e-04 - 36ms/epoch - 3ms/step
# Epoch 869/1000
# 11/11 - 0s - loss: 8.8348e-04 - 36ms/epoch - 3ms/step
# Epoch 870/1000
# 11/11 - 0s - loss: 9.0497e-04 - 36ms/epoch - 3ms/step
# Epoch 871/1000
# 11/11 - 0s - loss: 8.8537e-04 - 36ms/epoch - 3ms/step
# Epoch 872/1000
# 11/11 - 0s - loss: 0.0010 - 41ms/epoch - 4ms/step
# Epoch 873/1000
# 11/11 - 0s - loss: 0.0010 - 47ms/epoch - 4ms/step
# Epoch 874/1000
# 11/11 - 0s - loss: 8.9026e-04 - 35ms/epoch - 3ms/step
# Epoch 875/1000
# 11/11 - 0s - loss: 8.9414e-04 - 35ms/epoch - 3ms/step
# Epoch 876/1000
# 11/11 - 0s - loss: 8.9653e-04 - 34ms/epoch - 3ms/step
# Epoch 877/1000
# 11/11 - 0s - loss: 9.2758e-04 - 33ms/epoch - 3ms/step
# Epoch 878/1000
# 11/11 - 0s - loss: 8.7931e-04 - 35ms/epoch - 3ms/step
# Epoch 879/1000
# 11/11 - 0s - loss: 9.1813e-04 - 34ms/epoch - 3ms/step
# Epoch 880/1000
# 11/11 - 0s - loss: 8.8635e-04 - 33ms/epoch - 3ms/step
# Epoch 881/1000
# 11/11 - 0s - loss: 8.8137e-04 - 35ms/epoch - 3ms/step
# Epoch 882/1000
# 11/11 - 0s - loss: 8.9508e-04 - 37ms/epoch - 3ms/step
# Epoch 883/1000
# 11/11 - 0s - loss: 9.6991e-04 - 34ms/epoch - 3ms/step
# Epoch 884/1000
# 11/11 - 0s - loss: 9.3650e-04 - 35ms/epoch - 3ms/step
# Epoch 885/1000
# 11/11 - 0s - loss: 8.9442e-04 - 32ms/epoch - 3ms/step
# Epoch 886/1000
# 11/11 - 0s - loss: 8.7795e-04 - 38ms/epoch - 3ms/step
# Epoch 887/1000
# 11/11 - 0s - loss: 9.2384e-04 - 36ms/epoch - 3ms/step
# Epoch 888/1000
# 11/11 - 0s - loss: 9.1826e-04 - 35ms/epoch - 3ms/step
# Epoch 889/1000
# 11/11 - 0s - loss: 9.7070e-04 - 37ms/epoch - 3ms/step
# Epoch 890/1000
# 11/11 - 0s - loss: 0.0011 - 33ms/epoch - 3ms/step
# Epoch 891/1000
# 11/11 - 0s - loss: 9.6102e-04 - 33ms/epoch - 3ms/step
# Epoch 892/1000
# 11/11 - 0s - loss: 8.8072e-04 - 34ms/epoch - 3ms/step
# Epoch 893/1000
# 11/11 - 0s - loss: 8.8844e-04 - 34ms/epoch - 3ms/step
# Epoch 894/1000
# 11/11 - 0s - loss: 9.2309e-04 - 33ms/epoch - 3ms/step
# Epoch 895/1000
# 11/11 - 0s - loss: 9.0763e-04 - 34ms/epoch - 3ms/step
# Epoch 896/1000
# 11/11 - 0s - loss: 0.0010 - 33ms/epoch - 3ms/step
# Epoch 897/1000
# 11/11 - 0s - loss: 9.5512e-04 - 34ms/epoch - 3ms/step
# Epoch 898/1000
# 11/11 - 0s - loss: 9.5589e-04 - 43ms/epoch - 4ms/step
# Epoch 899/1000
# 11/11 - 0s - loss: 9.9338e-04 - 33ms/epoch - 3ms/step
# Epoch 900/1000
# 11/11 - 0s - loss: 8.7703e-04 - 36ms/epoch - 3ms/step
# Epoch 901/1000
# 11/11 - 0s - loss: 8.7987e-04 - 34ms/epoch - 3ms/step
# Epoch 902/1000
# 11/11 - 0s - loss: 8.8338e-04 - 33ms/epoch - 3ms/step
# Epoch 903/1000
# 11/11 - 0s - loss: 8.7717e-04 - 34ms/epoch - 3ms/step
# Epoch 904/1000
# 11/11 - 0s - loss: 9.3444e-04 - 34ms/epoch - 3ms/step
# Epoch 905/1000
# 11/11 - 0s - loss: 8.7367e-04 - 34ms/epoch - 3ms/step
# Epoch 906/1000
# 11/11 - 0s - loss: 8.8622e-04 - 33ms/epoch - 3ms/step
# Epoch 907/1000
# 11/11 - 0s - loss: 8.7221e-04 - 37ms/epoch - 3ms/step
# Epoch 908/1000
# 11/11 - 0s - loss: 8.7712e-04 - 34ms/epoch - 3ms/step
# Epoch 909/1000
# 11/11 - 0s - loss: 8.7754e-04 - 33ms/epoch - 3ms/step
# Epoch 910/1000
# 11/11 - 0s - loss: 8.7920e-04 - 37ms/epoch - 3ms/step
# Epoch 911/1000
# 11/11 - 0s - loss: 9.0167e-04 - 33ms/epoch - 3ms/step
# Epoch 912/1000
# 11/11 - 0s - loss: 9.7793e-04 - 38ms/epoch - 3ms/step
# Epoch 913/1000
# 11/11 - 0s - loss: 8.9147e-04 - 37ms/epoch - 3ms/step
# Epoch 914/1000
# 11/11 - 0s - loss: 0.0011 - 34ms/epoch - 3ms/step
# Epoch 915/1000
# 11/11 - 0s - loss: 9.1113e-04 - 33ms/epoch - 3ms/step
# Epoch 916/1000
# 11/11 - 0s - loss: 0.0011 - 34ms/epoch - 3ms/step
# Epoch 917/1000
# 11/11 - 0s - loss: 0.0010 - 35ms/epoch - 3ms/step
# Epoch 918/1000
# 11/11 - 0s - loss: 8.9299e-04 - 33ms/epoch - 3ms/step
# Epoch 919/1000
# 11/11 - 0s - loss: 8.7604e-04 - 33ms/epoch - 3ms/step
# Epoch 920/1000
# 11/11 - 0s - loss: 8.8023e-04 - 34ms/epoch - 3ms/step
# Epoch 921/1000
# 11/11 - 0s - loss: 9.3340e-04 - 36ms/epoch - 3ms/step
# Epoch 922/1000
# 11/11 - 0s - loss: 8.7592e-04 - 34ms/epoch - 3ms/step
# Epoch 923/1000
# 11/11 - 0s - loss: 8.7009e-04 - 58ms/epoch - 5ms/step
# Epoch 924/1000
# 11/11 - 0s - loss: 9.3580e-04 - 36ms/epoch - 3ms/step
# Epoch 925/1000
# 11/11 - 0s - loss: 8.8164e-04 - 38ms/epoch - 3ms/step
# Epoch 926/1000
# 11/11 - 0s - loss: 8.7521e-04 - 38ms/epoch - 3ms/step
# Epoch 927/1000
# 11/11 - 0s - loss: 8.8666e-04 - 37ms/epoch - 3ms/step
# Epoch 928/1000
# 11/11 - 0s - loss: 8.9469e-04 - 39ms/epoch - 4ms/step
# Epoch 929/1000
# 11/11 - 0s - loss: 8.7636e-04 - 32ms/epoch - 3ms/step
# Epoch 930/1000
# 11/11 - 0s - loss: 0.0010 - 35ms/epoch - 3ms/step
# Epoch 931/1000
# 11/11 - 0s - loss: 8.9898e-04 - 41ms/epoch - 4ms/step
# Epoch 932/1000
# 11/11 - 0s - loss: 8.7577e-04 - 35ms/epoch - 3ms/step
# Epoch 933/1000
# 11/11 - 0s - loss: 8.7299e-04 - 35ms/epoch - 3ms/step
# Epoch 934/1000
# 11/11 - 0s - loss: 8.8646e-04 - 36ms/epoch - 3ms/step
# Epoch 935/1000
# 11/11 - 0s - loss: 9.5884e-04 - 34ms/epoch - 3ms/step
# Epoch 936/1000
# 11/11 - 0s - loss: 0.0010 - 37ms/epoch - 3ms/step
# Epoch 937/1000
# 11/11 - 0s - loss: 8.8182e-04 - 35ms/epoch - 3ms/step
# Epoch 938/1000
# 11/11 - 0s - loss: 9.2171e-04 - 33ms/epoch - 3ms/step
# Epoch 939/1000
# 11/11 - 0s - loss: 9.1294e-04 - 34ms/epoch - 3ms/step
# Epoch 940/1000
# 11/11 - 0s - loss: 9.8795e-04 - 34ms/epoch - 3ms/step
# Epoch 941/1000
# 11/11 - 0s - loss: 9.4782e-04 - 33ms/epoch - 3ms/step
# Epoch 942/1000
# 11/11 - 0s - loss: 9.9740e-04 - 35ms/epoch - 3ms/step
# Epoch 943/1000
# 11/11 - 0s - loss: 8.8248e-04 - 36ms/epoch - 3ms/step
# Epoch 944/1000
# 11/11 - 0s - loss: 8.8440e-04 - 35ms/epoch - 3ms/step
# Epoch 945/1000
# 11/11 - 0s - loss: 9.1754e-04 - 39ms/epoch - 4ms/step
# Epoch 946/1000
# 11/11 - 0s - loss: 8.9170e-04 - 38ms/epoch - 3ms/step
# Epoch 947/1000
# 11/11 - 0s - loss: 9.2804e-04 - 35ms/epoch - 3ms/step
# Epoch 948/1000
# 11/11 - 0s - loss: 8.7122e-04 - 38ms/epoch - 3ms/step
# Epoch 949/1000
# 11/11 - 0s - loss: 8.7159e-04 - 38ms/epoch - 3ms/step
# Epoch 950/1000
# 11/11 - 0s - loss: 9.2569e-04 - 34ms/epoch - 3ms/step
# Epoch 951/1000
# 11/11 - 0s - loss: 9.3993e-04 - 36ms/epoch - 3ms/step
# Epoch 952/1000
# 11/11 - 0s - loss: 8.7674e-04 - 33ms/epoch - 3ms/step
# Epoch 953/1000
# 11/11 - 0s - loss: 9.0197e-04 - 34ms/epoch - 3ms/step
# Epoch 954/1000
# 11/11 - 0s - loss: 9.0044e-04 - 35ms/epoch - 3ms/step
# Epoch 955/1000
# 11/11 - 0s - loss: 8.8459e-04 - 34ms/epoch - 3ms/step
# Epoch 956/1000
# 11/11 - 0s - loss: 8.7116e-04 - 36ms/epoch - 3ms/step
# Epoch 957/1000
# 11/11 - 0s - loss: 8.7602e-04 - 36ms/epoch - 3ms/step
# Epoch 958/1000
# 11/11 - 0s - loss: 8.7912e-04 - 35ms/epoch - 3ms/step
# Epoch 959/1000
# 11/11 - 0s - loss: 0.0013 - 34ms/epoch - 3ms/step
# Epoch 960/1000
# 11/11 - 0s - loss: 0.0012 - 35ms/epoch - 3ms/step
# Epoch 961/1000
# 11/11 - 0s - loss: 0.0013 - 36ms/epoch - 3ms/step
# Epoch 962/1000
# 11/11 - 0s - loss: 9.7384e-04 - 35ms/epoch - 3ms/step
# Epoch 963/1000
# 11/11 - 0s - loss: 8.8993e-04 - 36ms/epoch - 3ms/step
# Epoch 964/1000
# 11/11 - 0s - loss: 9.7147e-04 - 38ms/epoch - 3ms/step
# Epoch 965/1000
# 11/11 - 0s - loss: 9.1889e-04 - 35ms/epoch - 3ms/step
# Epoch 966/1000
# 11/11 - 0s - loss: 8.7354e-04 - 35ms/epoch - 3ms/step
# Epoch 967/1000
# 11/11 - 0s - loss: 9.2117e-04 - 34ms/epoch - 3ms/step
# Epoch 968/1000
# 11/11 - 0s - loss: 8.8935e-04 - 34ms/epoch - 3ms/step
# Epoch 969/1000
# 11/11 - 0s - loss: 9.3472e-04 - 33ms/epoch - 3ms/step
# Epoch 970/1000
# 11/11 - 0s - loss: 8.9743e-04 - 34ms/epoch - 3ms/step
# Epoch 971/1000
# 11/11 - 0s - loss: 8.7678e-04 - 33ms/epoch - 3ms/step
# Epoch 972/1000
# 11/11 - 0s - loss: 9.9106e-04 - 36ms/epoch - 3ms/step
# Epoch 973/1000
# 11/11 - 0s - loss: 8.9146e-04 - 40ms/epoch - 4ms/step
# Epoch 974/1000
# 11/11 - 0s - loss: 9.1315e-04 - 45ms/epoch - 4ms/step
# Epoch 975/1000
# 11/11 - 0s - loss: 9.6702e-04 - 39ms/epoch - 4ms/step
# Epoch 976/1000
# 11/11 - 0s - loss: 8.9039e-04 - 35ms/epoch - 3ms/step
# Epoch 977/1000
# 11/11 - 0s - loss: 8.9626e-04 - 34ms/epoch - 3ms/step
# Epoch 978/1000
# 11/11 - 0s - loss: 8.9906e-04 - 35ms/epoch - 3ms/step
# Epoch 979/1000
# 11/11 - 0s - loss: 9.7846e-04 - 35ms/epoch - 3ms/step
# Epoch 980/1000
# 11/11 - 0s - loss: 8.9341e-04 - 34ms/epoch - 3ms/step
# Epoch 981/1000
# 11/11 - 0s - loss: 8.8344e-04 - 35ms/epoch - 3ms/step
# Epoch 982/1000
# 11/11 - 0s - loss: 8.9351e-04 - 37ms/epoch - 3ms/step
# Epoch 983/1000
# 11/11 - 0s - loss: 8.6891e-04 - 34ms/epoch - 3ms/step
# Epoch 984/1000
# 11/11 - 0s - loss: 9.4718e-04 - 34ms/epoch - 3ms/step
# Epoch 985/1000
# 11/11 - 0s - loss: 9.5096e-04 - 33ms/epoch - 3ms/step
# Epoch 986/1000
# 11/11 - 0s - loss: 9.0390e-04 - 34ms/epoch - 3ms/step
# Epoch 987/1000
# 11/11 - 0s - loss: 8.9227e-04 - 36ms/epoch - 3ms/step
# Epoch 988/1000
# 11/11 - 0s - loss: 9.1185e-04 - 33ms/epoch - 3ms/step
# Epoch 989/1000
# 11/11 - 0s - loss: 9.0663e-04 - 36ms/epoch - 3ms/step
# Epoch 990/1000
# 11/11 - 0s - loss: 8.7907e-04 - 35ms/epoch - 3ms/step
# Epoch 991/1000
# 11/11 - 0s - loss: 8.7916e-04 - 32ms/epoch - 3ms/step
# Epoch 992/1000
# 11/11 - 0s - loss: 8.8408e-04 - 32ms/epoch - 3ms/step
# Epoch 993/1000
# 11/11 - 0s - loss: 8.8098e-04 - 36ms/epoch - 3ms/step
# Epoch 994/1000
# 11/11 - 0s - loss: 9.3008e-04 - 33ms/epoch - 3ms/step
# Epoch 995/1000
# 11/11 - 0s - loss: 8.9041e-04 - 32ms/epoch - 3ms/step
# Epoch 996/1000
# 11/11 - 0s - loss: 0.0010 - 33ms/epoch - 3ms/step
# Epoch 997/1000
# 11/11 - 0s - loss: 9.2642e-04 - 36ms/epoch - 3ms/step
# Epoch 998/1000
# 11/11 - 0s - loss: 9.0061e-04 - 43ms/epoch - 4ms/step
# Epoch 999/1000
# 11/11 - 0s - loss: 8.8227e-04 - 36ms/epoch - 3ms/step
# Epoch 1000/1000
# 11/11 - 0s - loss: 8.8146e-04 - 43ms/epoch - 4ms/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 4)                 68
#
#  dense (Dense)               (None, 1)                 5
#
# =================================================================
# Total params: 73
# Trainable params: 73
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 1.3 Evaluate Predictive Model Performance (10 Points)
#
# Predict datapoints with the observed datapoints and trained model.
#
# **Tasks:**
# 1. Do direct prediction on train and test datapoints with the obtained model in section 1.2. **(2 Points)**
# 2. Scale the prediction results back to original representation with the scaler.(scaler.inverse_transform function) **(3 Points)**
# 3. Calculate root mean squared error (RMSE) and **print out** the error for **both TRAIN and TEST**. **(3 Points)**
# 4. **Plot** the **TEST** label and prediction. **(2 Points)**
#
#
# **Hints:**
# 1. Scale back the predictions with the build-in function "scaler.inverse_transform".\
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html#sklearn.preprocessing.MinMaxScaler.inverse_transform
# 2. For validation: Train Score: **~10.92 RMSE** Test Score: **~27.70 RMSE**
# 3. The plot for validation is shown below (observation test data are blue and prediction results are orange):
#
#
# ![](https://drive.google.com/uc?export=view&id=10c1Fsa_9v0AQf2fDpCzGPFPxbIEso81u)

# %%
### Make Predictions ###

trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# Out:
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step

# %%
### Scale Back Predictions ###

trainPredict = scaler.inverse_transform(trainPredict) # scale train prediction back with scaler.inverse_transform()
trainY = scaler.inverse_transform([trainY])  # scale train labels back with scaler.inverse_transform()

testPredict = scaler.inverse_transform(testPredict) # scale test prediction back with scaler.inverse_transform()
testY = scaler.inverse_transform([testY]) # scale test labels back with scaler.inverse_transform()

# %%
### Calculate Root Mean Squared Error (RMSE) ###
import math
from sklearn.metrics import mean_squared_error # Import mean_squared_error from sklearn.metrics

trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0])) 
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0])) 
print('Train Score: %.2f RMSE' % (trainScore))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 10.74 RMSE
# Test Score: 26.26 RMSE

# %%
### Plot Observation Data and Prediction Results with TEST dataset ###

import matplotlib.pyplot as plt
plt.plot(testY[0]) # Plot Observations in Test Set
plt.plot(testPredict) # Plot Predictions in Test Set

plt.show()

# %% [markdown]
# ## 2 - Build an LSTM model to conduct sentiment analysis ##
#
# ### 2.1 Prepare the data (13 Points) ###
#
# Prepare IMDB data for reccurent neural network training.
#
# **Tasks:**
# 1. Load the data from IMDB review dataset and **print out** the lengths of sequences. **(3 Points)**
# 2. Preprocess review data to meet the network input requirement by specifying **number of words=1000**, setting **the analysis length of the review = 100**, and **padding the input sequences**. **(10 Points)**
#
# **Hints:**
# 1. You may load the IMDB data with keras.datasets.imdb.load_data(num_words=max_features). Here. max_features is set to **1000**.
# 2. You may use keras.preprocessing.sequence.pad_sequences(x_train, maxlen) to pad the input sequences and set maxlen to **100**.
#
# **Note:**\
# We train the built LSTM-based model with ALL training data; the **validation set** (aka **development set**) is set with the **testing set** for model evaluation. This split is common in the application with limited sampled observation data, like NLP problems.

# %%
import tensorflow as tf
import tensorflow.keras as keras
from keras import layers
import random
import numpy as np


### Set random seed to ensure deterministic results
import os
seed_value = 1
os.environ['PYTHONHASHSEED']=str(seed_value)
def reset_random_seeds():
   tf.random.set_seed(seed_value)
   np.random.seed(seed_value)
   random.seed(seed_value)

reset_random_seeds() # randomly set initial data

# %%
# Prepare the data here

max_features = 1000 # Only consider the top 1k words
maxlen = 100 # Only consider the first 100 words of each movie review

(x_train, y_train), (x_val, y_val) = keras.datasets.imdb.load_data(num_words=1000, path='imdb.npz') # load IMDB data with specified num_words = 1000; testing set is set to validation set.
print(len(x_train), "Training sequences")
print(len(x_val), "Validation sequences")
x_train = keras.preprocessing.sequence.pad_sequences(x_train, maxlen=100) # Pad IMDB training data with specified maxlen=100
x_val = keras.preprocessing.sequence.pad_sequences(x_val, maxlen=100) # Pad IMDB validation data with specified maxlen=100
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 2s 0us/step
# 25000 Training sequences
# 25000 Validation sequences

# %% [markdown]
# ### 2.2 - Design and train LSTM model (25 Points) ###
#
# Build an LSTM model.
#
# **Tasks:**
# 1. Build the LSTM model with **1 embedding layer**, **1 LSTM layer**, and **1 Dense layer**. **Print out** model summary. The embedding vector is specified with the dimension of **8**. **(10 Points)**
# 2. Compile the LSTM model with **Adam** optimizer, **binary_crossentropy** loss function, and **accuracy** metrics. **(5 Points)**
# 3. Train the LSTM model with **batch_size=64 for 10 epochs** and report **training and validation accuracies over epochs**. **(5 Points)**
# 4. **Print out** best validation accuracy. **(5 Points)**
#
#
#
# **Hints:**
# 1. Set input dimension to **1000** and output dimension to **8** for embedding layer.
# 2. Set **unit_size=8** for LSTM layer.
# 3. Set activation function to **sigmoid** for Dense layer.
# 4. For validation: the outputs for first epoch should be close to（but maybe not exactly following） the statistics below:\
# - **-loss: ~0.6402 - accuracy: ~0.6187 - val_loss: ~0.4645 - val_accuracy: ~0.7995**
# 5. The model summary is as follows:
# - Total params: 8,553
# - Trainable params: 8,553
# - Non-trainable params: 0
#
# **Useful Reference:**
# 1. https://keras.io/examples/nlp/bidirectional_lstm_imdb/

# %%
### Model design with Embedding and LSTM layers ####
inputs = keras.Input(shape=(None,), dtype="int32") # This is an easy way to set an adaptive length for input sequence
x = layers.Embedding(input_dim=1000, output_dim=8)(inputs) # Embed data in an 8-dimensional vector
x = layers.LSTM(units=8)(x) # Add 1st layer of LSTM with 8 hidden states (aka units)
outputs = layers.Dense(units=1, activation="sigmoid")(x) # Add a classifier with units=1 and activation="sigmoid"

### Clear cached model to refresh memory and build new model for training ###
keras.backend.clear_session() # Clear cached model
model = keras.Model(inputs, outputs) # Build new keras model
model.summary() # Print out model summary

model.compile("adam", "binary_crossentropy", metrics=["accuracy"]) # Compile built model with "adam", "binary_crossentropy", and metrics=["accuracy"]
model.fit(x_train, y_train, batch_size=32, epochs=2, validation_data=(x_val, y_val)) # Train the compiled model with model.fit()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  embedding (Embedding)       (None, None, 8)           8000
#
#  lstm (LSTM)                 (None, 8)                 544
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 8,553
# Trainable params: 8,553
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
# 782/782 [==============================] - 13s 11ms/step - loss: 0.5195 - accuracy: 0.7361 - val_loss: 0.4198 - val_accuracy: 0.8094
# Epoch 2/2
# 782/782 [==============================] - 8s 10ms/step - loss: 0.3949 - accuracy: 0.8229 - val_loss: 0.3851 - val_accuracy: 0.8268

# %% [markdown]
# ### 2.3 - LSTM hyperparameter tuning (Bonus 15 Points) ###
#
# Boost the performance of obtained LSTM (aka vanilla model) by hyperparameter tuning.
#
# **Tasks:**
# Note:
# - All modificiations are directly conducted based on the vanilla model above (from 2.2).
# - For each scenario, **report <span style="color:red"> BEST Validation Accuracy </span> and generate Training/Validation <span style="color:red"> Accuracy plots over epochs</span>**. You may just paste the plot figures in the cells with **Markdown mode**, or leave the result after running. **Make sure it is already correctly shown in your submitted file.**
# 1.  Scenario 1 (**5 points**):
#     - Add one additional LSTM layer (totally 2 LSTM layers).
#     - Modify the embedding dimension to 16.
#     - Modify the units of LSTM to 16.
# 2. Scenario 2 (**5 points**)
#     - Add one additional LSTM layer (totally 2 LSTM layers).
#     - Modify the embedding dimension to 128.
#     - Modify the units of LSTM to 128.
# 3. Scenario 3 (**5 points**)
#     - Add one additional LSTM layer (totally 2 LSTM layers).
#     - Modify the embedding dimension to 128.
#     - Modify the units of LSTM to 128.
#     - Increase analysis length for review data to maxlen = 200
#
# **Hints:**
# For validation: the outputs for first epoch should be close to （but maybe not exactly following） the statistics below:
# - Scenario 1: **loss: ~0.5839 - accuracy: ~0.6524 - val_loss: ~0.4079 - val_accuracy: ~0.8198**
# - Scenario 2: **loss: ~0.5572 - accuracy: ~0.6911 - val_loss: ~0.3953 - val_accuracy: ~0.8244**
# - Scenario 3: **loss: ~0.5605 - accuracy: ~0.6914 - val_loss: ~0.3402 - val_accuracy: ~0.8560**
#
# - Summary of Model 1: Total params: 20,241; Trainable params: 20,241; Non-trainable params: 0
# - Summary of Model 2: Total params: 391,297; Trainable params: 391,297; Non-trainable params: 0
# - Summary of Model 3: Total params: 391,297; Trainable params: 391,297; Non-trainable params: 0
#
# You may follow the example from the reference below to add additional LSTM layer.
#
# **Useful Reference:**
# 1. https://keras.io/examples/nlp/bidirectional_lstm_imdb/

# %%
########################### Scenario 1 ###########################
##################################################################

### Set random seed to ensure deterministic results ###
import os
seed_value = 1
os.environ['PYTHONHASHSEED']=str(seed_value)
def reset_random_seeds():
   tf.random.set_seed(seed_value)
   np.random.seed(seed_value)
   random.seed(seed_value)

reset_random_seeds() # randomly set initial data

max_features = 1000 # Only consider the top 1k words
maxlen = 100 # Only consider the first 100 words of each movie review

### Model design with Embedding and LSTM layers ####
inputs = keras.Input(shape=(None,), dtype="int32") # This is an easy way to set an adaptive length for input sequence
x = layers.Embedding(input_dim=1000, output_dim=16)(inputs) # Embed data in a 16-dimensional vector
x = layers.LSTM(units=16, return_sequences=True)(x) # Add 1st layer of LSTM with 16 hidden states (aka units); set return_sequences=true.
x = layers.LSTM(units=16)(x) # Add 2nd layer of LSTM with 16 hidden states (aka units)
outputs = layers.Dense(units=1, activation="sigmoid")(x) # Add a classifier with units=1 and activation="sigmoid"

### Clear cached model to refresh memory and build new model for training ###
keras.backend.clear_session() # Clear cached model
model = keras.Model(inputs, outputs) # Build new keras model
model.summary() # Print out model summary

model.compile("adam", "binary_crossentropy", metrics=["accuracy"]) # Compile built model with "adam", "binary_crossentropy", and metrics=["accuracy"]
model.fit(x_train, y_train, batch_size=64, epochs=10, validation_data=(x_val, y_val)) # Train the compiled model using model.fit() with batch_size=64, epochs=10, and validation_data=(x_val, y_val)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  embedding (Embedding)       (None, None, 16)          16000
#
#  lstm (LSTM)                 (None, None, 16)          2112
#
#  lstm_1 (LSTM)               (None, 16)                2112
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 20,241
# Trainable params: 20,241
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 11s 20ms/step - loss: 0.4968 - accuracy: 0.7450 - val_loss: 0.4079 - val_accuracy: 0.8198
# Epoch 2/10
# 391/391 [==============================] - 6s 15ms/step - loss: 0.3883 - accuracy: 0.8286 - val_loss: 0.3844 - val_accuracy: 0.8242
# Epoch 3/10
# 391/391 [==============================] - 6s 16ms/step - loss: 0.3688 - accuracy: 0.8382 - val_loss: 0.3692 - val_accuracy: 0.8333
# Epoch 4/10
# 391/391 [==============================] - 6s 16ms/step - loss: 0.3541 - accuracy: 0.8436 - val_loss: 0.3798 - val_accuracy: 0.8257
# Epoch 5/10
# 391/391 [==============================] - 6s 15ms/step - loss: 0.3446 - accuracy: 0.8464 - val_loss: 0.3665 - val_accuracy: 0.8338
# Epoch 6/10
# 391/391 [==============================] - 6s 16ms/step - loss: 0.3353 - accuracy: 0.8520 - val_loss: 0.4104 - val_accuracy: 0.8247
# Epoch 7/10
# 391/391 [==============================] - 7s 17ms/step - loss: 0.3257 - accuracy: 0.8540 - val_loss: 0.3680 - val_accuracy: 0.8325
# Epoch 8/10
# 391/391 [==============================] - 6s 15ms/step - loss: 0.3188 - accuracy: 0.8594 - val_loss: 0.3659 - val_accuracy: 0.8334
# Epoch 9/10
# 391/391 [==============================] - 6s 16ms/step - loss: 0.3110 - accuracy: 0.8602 - val_loss: 0.3800 - val_accuracy: 0.8334
# Epoch 10/10
# 391/391 [==============================] - 6s 16ms/step - loss: 0.3048 - accuracy: 0.8656 - val_loss: 0.3928 - val_accuracy: 0.8343

# %%
########################### Scenario 2 ###########################
##################################################################

### Set random seed to ensure deterministic results ###
import os
seed_value = 1
os.environ['PYTHONHASHSEED']=str(seed_value)
def reset_random_seeds():
   tf.random.set_seed(seed_value)
   np.random.seed(seed_value)
   random.seed(seed_value)

reset_random_seeds() # randomly set initial data

max_features = 1000 # Only consider the top 1k words
maxlen = 100 # Only consider the first 100 words of each movie review

### Model design with Embedding and LSTM layers ####
inputs = keras.Input(shape=(None,), dtype="int32") # This is an easy way to set an adaptive length for input sequence
x = layers.Embedding(input_dim=1000, output_dim=128)(inputs) # Embed data in a 128-dimensional vector
x = layers.LSTM(units=128, return_sequences=True)(x) # Add 1st layer of LSTM with 128 hidden states (aka units); set return_sequences=true.
x = layers.LSTM(units=128)(x) # Add 2nd layer of LSTM with 128 hidden states (aka units)
outputs = layers.Dense(units=1, activation="sigmoid")(x) # Add a classifier with units=1 and activation="sigmoid"

### Clear cached model to refresh memory and build new model for training ###
keras.backend.clear_session() # Clear cached model
model = keras.Model(inputs, outputs) # Build new keras model
model.summary() # Print out model summary

model.compile("adam", "binary_crossentropy", metrics=["accuracy"]) # Compile built model with "adam", "binary_crossentropy", and metrics=["accuracy"]
model.fit(x_train, y_train, batch_size=64, epochs=10, validation_data=(x_val, y_val)) # Train the compiled model using model.fit() with batch_size=64, epochs=10, and validation_data=(x_val, y_val)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  embedding (Embedding)       (None, None, 128)         128000
#
#  lstm (LSTM)                 (None, None, 128)         131584
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 391,297
# Trainable params: 391,297
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 13s 26ms/step - loss: 0.4798 - accuracy: 0.7612 - val_loss: 0.4128 - val_accuracy: 0.8180
# Epoch 2/10
# 391/391 [==============================] - 8s 21ms/step - loss: 0.4120 - accuracy: 0.8132 - val_loss: 0.3833 - val_accuracy: 0.8255
# Epoch 3/10
# 391/391 [==============================] - 8s 21ms/step - loss: 0.3674 - accuracy: 0.8357 - val_loss: 0.3795 - val_accuracy: 0.8334
# Epoch 4/10
# 391/391 [==============================] - 8s 21ms/step - loss: 0.3465 - accuracy: 0.8480 - val_loss: 0.3913 - val_accuracy: 0.8303
# Epoch 5/10
# 391/391 [==============================] - 9s 24ms/step - loss: 0.3296 - accuracy: 0.8570 - val_loss: 0.3640 - val_accuracy: 0.8373
# Epoch 6/10
# 391/391 [==============================] - 8s 21ms/step - loss: 0.3090 - accuracy: 0.8673 - val_loss: 0.3809 - val_accuracy: 0.8380
# Epoch 7/10
# 391/391 [==============================] - 8s 21ms/step - loss: 0.2904 - accuracy: 0.8776 - val_loss: 0.3610 - val_accuracy: 0.8411
# Epoch 8/10
# 391/391 [==============================] - 8s 21ms/step - loss: 0.2780 - accuracy: 0.8811 - val_loss: 0.3603 - val_accuracy: 0.8403
# Epoch 9/10
# 391/391 [==============================] - 8s 21ms/step - loss: 0.2617 - accuracy: 0.8897 - val_loss: 0.3715 - val_accuracy: 0.8322
# Epoch 10/10
# 391/391 [==============================] - 13s 33ms/step - loss: 0.2446 - accuracy: 0.9010 - val_loss: 0.3768 - val_accuracy: 0.8416

# %%
########################### Scenario 3 ###########################
##################################################################

### Set random seed to ensure deterministic results ###
import os
seed_value = 1
os.environ['PYTHONHASHSEED']=str(seed_value)
def reset_random_seeds():
   tf.random.set_seed(seed_value)
   np.random.seed(seed_value)
   random.seed(seed_value)

reset_random_seeds() # randomly set initial data

max_features = 1000  # Only consider the top 1k words
maxlen = 200 # Only consider the first 200 words of each movie review

### Model design with Embedding and LSTM layers ####
inputs = keras.Input(shape=(None,), dtype="int32") # This is an easy way to set an adaptive length for input sequence
x = layers.Embedding(input_dim=1000, output_dim=128)(inputs) # Embed data in a 128-dimensional vector
x = layers.LSTM(units=128, return_sequences=True)(x) # Add 1st layer of LSTM with 128 hidden states (aka units); set return_sequences=true.
x = layers.LSTM(units=128)(x) # Add 2nd layer of LSTM with 128 hidden states (aka units)
outputs = layers.Dense(units=1, activation="sigmoid")(x) # Add a classifier with units=1 and activation="sigmoid"

### Clear cached model to refresh memory and build new model for training ###
keras.backend.clear_session() # Clear cached model
model = keras.Model(inputs, outputs) # Build new keras model
model.summary() # Print out model summary

model.compile("adam", "binary_crossentropy", metrics=["accuracy"]) # Compile built model with "adam", "binary_crossentropy", and metrics=["accuracy"]
model.fit(x_train, y_train, batch_size=64, epochs=10, validation_data=(x_val, y_val)) # Train the compiled model using model.fit() with batch_size=64, epochs=10, and validation_data=(x_val, y_val)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  embedding (Embedding)       (None, None, 128)         128000
#
#  lstm (LSTM)                 (None, None, 128)         131584
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 391,297
# Trainable params: 391,297
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 13s 26ms/step - loss: 0.4785 - accuracy: 0.7640 - val_loss: 0.4070 - val_accuracy: 0.8155
# Epoch 2/10
# 391/391 [==============================] - 8s 21ms/step - loss: 0.3835 - accuracy: 0.8288 - val_loss: 0.3758 - val_accuracy: 0.8312
# Epoch 3/10
# 391/391 [==============================] - 8s 21ms/step - loss: 0.3558 - accuracy: 0.8414 - val_loss: 0.3672 - val_accuracy: 0.8348
# Epoch 4/10
# 391/391 [==============================] - 8s 21ms/step - loss: 0.3317 - accuracy: 0.8552 - val_loss: 0.3646 - val_accuracy: 0.8398
# Epoch 5/10
# 391/391 [==============================] - 8s 21ms/step - loss: 0.3140 - accuracy: 0.8647 - val_loss: 0.3620 - val_accuracy: 0.8397
# Epoch 6/10
# 391/391 [==============================] - 9s 23ms/step - loss: 0.2941 - accuracy: 0.8724 - val_loss: 0.3602 - val_accuracy: 0.8408
# Epoch 7/10
# 391/391 [==============================] - 8s 21ms/step - loss: 0.2766 - accuracy: 0.8833 - val_loss: 0.3639 - val_accuracy: 0.8380
# Epoch 8/10
# 391/391 [==============================] - 8s 21ms/step - loss: 0.2670 - accuracy: 0.8870 - val_loss: 0.3778 - val_accuracy: 0.8372
# Epoch 9/10
# 391/391 [==============================] - 8s 21ms/step - loss: 0.2454 - accuracy: 0.8989 - val_loss: 0.3835 - val_accuracy: 0.8255
# Epoch 10/10
# 391/391 [==============================] - 9s 24ms/step - loss: 0.2253 - accuracy: 0.9078 - val_loss: 0.4313 - val_accuracy: 0.8323
